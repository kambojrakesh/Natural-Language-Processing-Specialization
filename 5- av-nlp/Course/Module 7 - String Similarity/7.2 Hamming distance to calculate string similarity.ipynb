# %%
# importing the library
from scipy.spatial import distance

# %%
# defining two strings
string_1 = 'scientist'
string_2 = 'science'

# %%
# computing the normalized hamming distance
hamming_distance = distance.hamming(list(string_1), list(string_2))
print('Normalized Hamming Distance b/w', string_1, 'and', string_2, 'is: ', hamming_distance)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-3e55dce455d7> in <module>()
#       1 # computing the normalized hamming distance
# ----> 2 hamming_distance = distance.hamming(list(string_1), list(string_2))
#       3 print('Normalized Hamming Distance b/w', string_1, 'and', string_2, 'is: ', hamming_distance)
#
# /usr/local/lib/python3.6/dist-packages/scipy/spatial/distance.py in hamming(u, v, w)
#     814     v = _validate_vector(v)
#     815     if u.shape != v.shape:
# --> 816         raise ValueError('The 1d arrays must have equal lengths.')
#     817     u_ne_v = u != v
#     818     if w is not None:
#
# ValueError: The 1d arrays must have equal lengths.

# %%
# original hamming distance
print('Hamming Distance b/w', string_1, 'and', string_2, 'is: ', hamming_distance * len(string_1))
# Out:
# Hamming Distance b/w scientist and science is:  5.3999999999999995
