# %% [markdown]
# ## Table of Contents
#
# 1. Loading the dataset
# 2. Data Pre-processing
# 3. Rule 1 - Extracting the sentences with President's mention
# 4. Rule 2 - Extracting the mentions of initiatives
# 5. Rule 3 - Relation Extraction part 1
# 6. Rule 4 - Relation Extraction part 2
# 7. Combining Rule 3 and Rule 4
# 8. Rule 5: Patterns using Preposition

# %% [markdown]
# ## 1. Loading the dataset

# %%
# mounting the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# extract the zip file
# !unzip '/content/drive/My Drive/UNGDC+1970-2018.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._PHL_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/DZA_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._DZA_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/MEX_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._MEX_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/AUT_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._AUT_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/COG_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._COG_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/CYP_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._CYP_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/SLB_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._SLB_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/ATG_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._ATG_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/TJK_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._TJK_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/CAF_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._CAF_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/BGD_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._BGD_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/BRN_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._BRN_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/MYS_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._MYS_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/BHS_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._BHS_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/GIN_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._GIN_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/DNK_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._DNK_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/GNQ_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._GNQ_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/SYR_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._SYR_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/SRB_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._SRB_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/BOL_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._BOL_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/IDN_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._IDN_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/RUS_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._RUS_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/MDG_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._MDG_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/EST_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._EST_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/ALB_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._ALB_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/SWZ_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._SWZ_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/TUN_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._TUN_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/NRU_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._NRU_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/NOR_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._NOR_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/BTN_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._BTN_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/BRB_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._BRB_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/SWE_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._SWE_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/JOR_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._JOR_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/ARG_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._ARG_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/IND_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._IND_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/PSE_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._PSE_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/PER_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._PER_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/LTU_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._LTU_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/SVN_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._SVN_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/SYC_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._SYC_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/CHL_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._CHL_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/TON_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._TON_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/TLS_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._TLS_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/COL_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._COL_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/DEU_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._DEU_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/GMB_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._GMB_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/SLV_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._SLV_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/GEO_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._GEO_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/FIN_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._FIN_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/KAZ_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._KAZ_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/TUV_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._TUV_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/CIV_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._CIV_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/HND_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._HND_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/MKD_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._MKD_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/KOR_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._KOR_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/SGP_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._SGP_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/ISR_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._ISR_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/KNA_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._KNA_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/VUT_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._VUT_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/CHE_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._CHE_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/CUB_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._CUB_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/ERI_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._ERI_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/KHM_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._KHM_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/MDV_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._MDV_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/KEN_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._KEN_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/AUS_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._AUS_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/NLD_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._NLD_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/MMR_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._MMR_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/TGO_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._TGO_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/SLE_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._SLE_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/LBN_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._LBN_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/KGZ_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._KGZ_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/NZL_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._NZL_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/EGY_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._EGY_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/UGA_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._UGA_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/CPV_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._CPV_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/FJI_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._FJI_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/TZA_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._TZA_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/NIC_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._NIC_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/SVK_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._SVK_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/PNG_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._PNG_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/ARE_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._ARE_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/TCD_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._TCD_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/LVA_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._LVA_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/KIR_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._KIR_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/ITA_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._ITA_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/AGO_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._AGO_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/LSO_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._LSO_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/BLZ_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._BLZ_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/SOM_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._SOM_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/YEM_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._YEM_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/JAM_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._JAM_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/IRQ_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._IRQ_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/MLT_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._MLT_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/SEN_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._SEN_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/DMA_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._DMA_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/NGA_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._NGA_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/NAM_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._NAM_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/IRN_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._IRN_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/BIH_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._BIH_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/KWT_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._KWT_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/MNE_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._MNE_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/LAO_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._LAO_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/UKR_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._UKR_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/CMR_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._CMR_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/LBR_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._LBR_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/NPL_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._NPL_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/VAT_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._VAT_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/MWI_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._MWI_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/BEN_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._BEN_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/LCA_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._LCA_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/GRD_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._GRD_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/ROU_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._ROU_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/STP_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._STP_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/MCO_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._MCO_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/BHR_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._BHR_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/AND_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._AND_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/GAB_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._GAB_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/HRV_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._HRV_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/THA_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._THA_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/PRY_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._PRY_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/BWA_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._BWA_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/TTO_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._TTO_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/ZAF_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._ZAF_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/USA_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._USA_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/QAT_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._QAT_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/MOZ_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._MOZ_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/SDN_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._SDN_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/GTM_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._GTM_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/MAR_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._MAR_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/CAN_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._CAN_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/MHL_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._MHL_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/CZE_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._CZE_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/HTI_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._HTI_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/MRT_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._MRT_63_2008.txt
#   inflating: Converted sessions/Session 63 - 2008/ESP_63_2008.txt
#   inflating: __MACOSX/Converted sessions/Session 63 - 2008/._ESP_63_2008.txt
#   inflating: __MACOSX/Converted sessions/._Session 63 - 2008
#    creating: Converted sessions/Session 40 - 1985/
#   inflating: Converted sessions/Session 40 - 1985/SWZ_40_1985.txt
#    creating: __MACOSX/Converted sessions/Session 40 - 1985/
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._SWZ_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/ALB_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._ALB_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/TUN_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._TUN_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/NOR_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._NOR_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/MDG_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._MDG_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/JOR_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._JOR_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/SWE_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._SWE_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/IND_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._IND_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/ARG_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._ARG_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/BRB_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._BRB_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/DNK_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._DNK_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/GIN_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._GIN_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/BHS_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._BHS_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/DJI_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._DJI_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/RUS_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._RUS_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/BOL_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._BOL_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/SYR_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._SYR_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/IDN_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._IDN_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/SLB_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._SLB_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/AUT_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._AUT_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/MEX_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._MEX_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/COG_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._COG_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/CYP_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._CYP_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/DDR_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._DDR_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/BGD_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._BGD_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/CAF_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._CAF_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/MYS_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._MYS_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/BRN_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._BRN_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/GBR_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._GBR_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/BGR_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._BGR_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/CRI_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._CRI_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/PRT_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._PRT_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/BFA_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._BFA_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/ECU_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._ECU_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/CHN_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._CHN_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/DZA_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._DZA_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/LKA_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._LKA_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/POL_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._POL_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/PHL_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._PHL_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/ZWE_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._ZWE_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/LUX_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._LUX_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/COM_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._COM_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/AFG_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._AFG_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/PAN_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._PAN_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/SUR_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._SUR_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/GRC_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._GRC_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/HUN_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._HUN_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/YUG_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._YUG_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/ISL_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._ISL_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/VEN_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._VEN_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/COD_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._COD_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/BLR_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._BLR_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/WSM_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._WSM_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/GHA_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._GHA_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/BEL_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._BEL_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/JPN_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._JPN_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/RWA_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._RWA_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/GUY_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._GUY_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/ETH_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._ETH_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/DOM_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._DOM_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/LBY_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._LBY_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/BRA_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._BRA_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/TUR_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._TUR_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/MUS_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._MUS_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/NER_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._NER_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/IRL_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._IRL_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/FRA_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._FRA_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/PAK_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._PAK_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/MLI_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._MLI_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/VNM_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._VNM_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/BDI_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._BDI_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/MNG_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._MNG_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/OMN_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._OMN_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/CAN_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._CAN_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/MAR_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._MAR_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/HTI_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._HTI_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/ESP_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._ESP_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/MRT_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._MRT_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/TTO_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._TTO_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/SDN_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._SDN_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/MOZ_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._MOZ_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/GTM_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._GTM_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/USA_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._USA_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/QAT_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._QAT_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/MWI_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._MWI_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/BEN_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._BEN_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/STP_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._STP_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/ROU_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._ROU_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/LAO_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._LAO_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/UKR_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._UKR_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/CMR_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._CMR_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/LBR_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._LBR_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/NPL_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._NPL_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/PRY_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._PRY_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/THA_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._THA_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/BHR_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._BHR_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/NGA_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._NGA_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/JAM_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._JAM_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/SOM_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._SOM_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/YEM_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._YEM_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/MLT_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._MLT_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/IRQ_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._IRQ_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/KWT_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._KWT_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/YDYE_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._YDYE_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/IRN_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._IRN_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/PNG_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._PNG_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/TZA_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._TZA_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/BLZ_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._BLZ_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/TCD_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._TCD_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/ARE_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._ARE_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/AGO_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._AGO_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/ITA_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._ITA_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/SLE_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._SLE_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/AUS_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._AUS_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/NLD_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._NLD_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/MMR_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._MMR_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/TGO_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._TGO_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/CSK_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._CSK_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/UGA_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._UGA_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/NZL_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._NZL_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/EGY_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._EGY_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/VUT_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._VUT_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/KNA_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._KNA_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/ISR_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._ISR_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/CUB_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._CUB_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/HND_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._HND_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/SGP_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._SGP_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/URY_49_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._URY_49_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/KEN_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._KEN_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/KHM_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._KHM_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/CHL_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._CHL_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/DEU_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._DEU_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/COL_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._COL_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/PER_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._PER_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/FIN_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._FIN_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/SAU_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._SAU_40_1985.txt
#   inflating: Converted sessions/Session 40 - 1985/SLV_40_1985.txt
#   inflating: __MACOSX/Converted sessions/Session 40 - 1985/._SLV_40_1985.txt
#   inflating: __MACOSX/Converted sessions/._Session 40 - 1985
#    creating: Converted sessions/Session 55 - 2000/
#   inflating: Converted sessions/Session 55 - 2000/BHS_55_2000.txt
#    creating: __MACOSX/Converted sessions/Session 55 - 2000/
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._BHS_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/GIN_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._GIN_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/DNK_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._DNK_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/SYR_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._SYR_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/GNQ_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._GNQ_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/BOL_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._BOL_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/IDN_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._IDN_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/DJI_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._DJI_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/RUS_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._RUS_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/MDG_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._MDG_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/EST_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._EST_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/ALB_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._ALB_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/SWZ_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._SWZ_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/NOR_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._NOR_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/TUN_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._TUN_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/NRU_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._NRU_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/BRB_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._BRB_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/SWE_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._SWE_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/JOR_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._JOR_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/ARG_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._ARG_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/IND_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._IND_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/ECU_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._ECU_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/PRT_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._PRT_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/BFA_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._BFA_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/CRI_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._CRI_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/CHN_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._CHN_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/GNB_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._GNB_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/GBR_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._GBR_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/BGR_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._BGR_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/PRK_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._PRK_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/LKA_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._LKA_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/POL_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._POL_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/PHL_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._PHL_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/DZA_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._DZA_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/MEX_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._MEX_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/AUT_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._AUT_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/COG_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._COG_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/CYP_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._CYP_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/SLB_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._SLB_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/ATG_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._ATG_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/TJK_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._TJK_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/CAF_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._CAF_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/BGD_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._BGD_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/BRN_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._BRN_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/MYS_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._MYS_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/LIE_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._LIE_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/VEN_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._VEN_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/GRC_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._GRC_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/AZE_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._AZE_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/ISL_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._ISL_55_2000.txt
#   inflating: Converted sessions/Session 55 - 2000/HUN_55_2000.txt
#   inflating: __MACOSX/Converted sessions/Session 55 - 2000/._HUN_55_2000.txt
# ...
#   inflating: Converted sessions/Session 69 - 2014/TZA_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._TZA_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/NIC_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._NIC_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/SVK_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._SVK_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/PNG_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._PNG_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/NZL_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._NZL_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/EGY_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._EGY_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/UGA_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._UGA_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/CPV_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._CPV_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/AUS_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._AUS_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/NLD_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._NLD_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/MMR_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._MMR_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/TGO_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._TGO_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/SLE_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._SLE_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/LBN_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._LBN_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/KGZ_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._KGZ_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/CAF_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._CAF_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/BGD_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._BGD_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/BRN_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._BRN_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/MYS_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._MYS_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/MEX_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._MEX_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/AUT_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._AUT_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/COG_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._COG_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/CYP_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._CYP_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/SLB_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._SLB_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/ATG_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._ATG_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/TJK_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._TJK_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/LKA_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._LKA_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/POL_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._POL_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/PRK_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._PRK_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/PHL_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._PHL_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/DZA_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._DZA_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/ECU_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._ECU_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/CRI_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._CRI_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/PRT_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._PRT_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/BFA_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._BFA_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/CHN_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._CHN_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/GNB_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._GNB_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/GBR_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._GBR_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/BGR_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._BGR_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/BRB_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._BRB_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/SWE_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._SWE_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/JOR_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._JOR_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/ARG_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._ARG_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/IND_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._IND_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/MDG_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._MDG_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/EST_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._EST_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/ALB_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._ALB_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/SWZ_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._SWZ_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/TUN_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._TUN_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/NRU_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._NRU_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/NOR_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._NOR_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/BTN_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._BTN_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/SYR_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._SYR_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/GNQ_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._GNQ_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/SRB_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._SRB_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/BOL_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._BOL_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/IDN_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._IDN_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/RUS_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._RUS_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/BHS_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._BHS_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/GIN_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._GIN_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/DNK_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._DNK_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/GUY_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._GUY_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/RWA_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._RWA_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/JPN_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._JPN_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/ARM_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._ARM_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/WSM_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._WSM_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/GHA_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._GHA_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/BEL_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._BEL_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/BLR_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._BLR_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/SSD_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._SSD_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/MNG_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._MNG_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/OMN_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._OMN_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/FRA_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._FRA_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/PAK_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._PAK_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/MLI_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._MLI_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/MUS_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._MUS_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/NER_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._NER_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/IRL_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._IRL_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/VNM_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._VNM_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/BDI_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._BDI_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/PLW_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._PLW_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/TUR_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._TUR_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/FSM_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._FSM_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/DOM_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._DOM_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/ETH_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._ETH_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/EU_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._EU_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/LBY_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._LBY_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/BRA_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._BRA_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/MDA_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._MDA_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/AFG_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._AFG_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/SUR_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._SUR_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/PAN_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._PAN_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/URY_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._URY_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/COM_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._COM_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/VCT_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._VCT_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/ZWE_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._ZWE_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/ZMB_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._ZMB_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/LUX_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._LUX_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/TKM_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._TKM_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/SMR_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._SMR_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/COD_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._COD_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/UZB_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._UZB_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/VEN_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._VEN_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/LIE_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._LIE_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/AZE_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._AZE_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/GRC_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._GRC_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/ISL_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._ISL_69_2014.txt
#   inflating: Converted sessions/Session 69 - 2014/HUN_69_2014.txt
#   inflating: __MACOSX/Converted sessions/Session 69 - 2014/._HUN_69_2014.txt
#   inflating: __MACOSX/Converted sessions/._Session 69 - 2014
#   inflating: __MACOSX/._Converted sessions

# %%
# folders of different sessions of speeches
# !ls Converted\ sessions
# Out:
# 'Session 25 - 1970'  'Session 42 - 1987'  'Session 59 - 2004'
# 'Session 26 - 1971'  'Session 43 - 1988'  'Session 60 - 2005'
# 'Session 27 - 1972'  'Session 44 - 1989'  'Session 61 - 2006'
# 'Session 28 - 1973'  'Session 45 - 1990'  'Session 62 - 2007'
# 'Session 29 - 1974'  'Session 46 - 1991'  'Session 63 - 2008'
# 'Session 30 - 1975'  'Session 47 - 1992'  'Session 64 - 2009'
# 'Session 31 - 1976'  'Session 48 - 1993'  'Session 65 - 2010'
# 'Session 32 - 1977'  'Session 49 - 1994'  'Session 66 - 2011'
# 'Session 33 - 1978'  'Session 50 - 1995'  'Session 67 - 2012'
# 'Session 34 - 1979'  'Session 51 - 1996'  'Session 68 - 2013'
# 'Session 35 - 1980'  'Session 52 - 1997'  'Session 69 - 2014'
# 'Session 36 - 1981'  'Session 53 - 1998'  'Session 70 - 2015'
# 'Session 37 - 1982'  'Session 54 - 1999'  'Session 71 - 2016'
# 'Session 38 - 1983'  'Session 55 - 2000'  'Session 72 - 2017'
# 'Session 39 - 1984'  'Session 56 - 2001'  'Session 73 - 2018'
# 'Session 40 - 1985'  'Session 57 - 2002'
# 'Session 41 - 1986'  'Session 58 - 2003'

# %%
# speeches in a single folder
# !ls Converted\ sessions/Session\ 25\ -\ 1970
# Out:
# ALB_25_1970.txt  GBR_25_1970.txt  LBN_25_1970.txt  SLE_25_1970.txt
# ARG_25_1970.txt  GHA_25_1970.txt  LBR_25_1970.txt  SLV_25_1970.txt
# AUS_25_1970.txt  GIN_25_1970.txt  LBY_25_1970.txt  SOM_25_1970.txt
# AUT_25_1970.txt  GMB_25_1970.txt  LKA_25_1970.txt  SYR_25_1970.txt
# BEL_25_1970.txt  GTM_25_1970.txt  MAR_25_1970.txt  TGO_25_1970.txt
# BLR_25_1970.txt  HND_25_1970.txt  MDG_25_1970.txt  THA_25_1970.txt
# BOL_25_1970.txt  HTI_25_1970.txt  MEX_25_1970.txt  TTO_25_1970.txt
# BRA_25_1970.txt  IDN_25_1970.txt  MMR_25_1970.txt  TUN_25_1970.txt
# CAN_25_1970.txt  IND_25_1970.txt  NLD_25_1970.txt  TUR_25_1970.txt
# CMR_25_1970.txt  IRN_25_1970.txt  NOR_25_1970.txt  UKR_25_1970.txt
# COG_25_1970.txt  IRQ_25_1970.txt  NZL_25_1970.txt  URY_25_1970.txt
# COL_25_1970.txt  ISL_25_1970.txt  PAK_25_1970.txt  USA_25_1970.txt
# CRI_25_1970.txt  ISR_25_1970.txt  PER_25_1970.txt  VEN_25_1970.txt
# CUB_25_1970.txt  ITA_25_1970.txt  PHL_25_1970.txt  YUG_25_1970.txt
# DOM_25_1970.txt  JPN_25_1970.txt  PRY_25_1970.txt  ZAF_25_1970.txt
# DZA_25_1970.txt  KEN_25_1970.txt  RWA_25_1970.txt  ZMB_25_1970.txt
# ECU_25_1970.txt  KHM_25_1970.txt  SDN_25_1970.txt
# FRA_25_1970.txt  KWT_25_1970.txt  SGP_25_1970.txt

# %% [markdown]
# ## 2. Data Pre-processing

# %%
# importing libraries
import glob
import pandas as pd
import re

# %%
# names of all the folders in the dataset
folders = glob.glob('Converted sessions/Session*')

# %%
# list of folders
folders
# Out:
# ['Converted sessions/Session 27 - 1972',
#  'Converted sessions/Session 47 - 1992',
#  'Converted sessions/Session 54 - 1999',
#  'Converted sessions/Session 57 - 2002',
#  'Converted sessions/Session 56 - 2001',
#  'Converted sessions/Session 52 - 1997',
#  'Converted sessions/Session 35 - 1980',
#  'Converted sessions/Session 48 - 1993',
#  'Converted sessions/Session 55 - 2000',
#  'Converted sessions/Session 29 - 1974',
#  'Converted sessions/Session 36 - 1981',
#  'Converted sessions/Session 40 - 1985',
#  'Converted sessions/Session 34 - 1979',
#  'Converted sessions/Session 60 - 2005',
#  'Converted sessions/Session 26 - 1971',
#  'Converted sessions/Session 63 - 2008',
#  'Converted sessions/Session 71 - 2016',
#  'Converted sessions/Session 42 - 1987',
#  'Converted sessions/Session 28 - 1973',
#  'Converted sessions/Session 37 - 1982',
#  'Converted sessions/Session 39 - 1984',
#  'Converted sessions/Session 32 - 1977',
#  'Converted sessions/Session 53 - 1998',
#  'Converted sessions/Session 59 - 2004',
#  'Converted sessions/Session 73 - 2018',
#  'Converted sessions/Session 45 - 1990',
#  'Converted sessions/Session 66 - 2011',
#  'Converted sessions/Session 69 - 2014',
#  'Converted sessions/Session 62 - 2007',
#  'Converted sessions/Session 44 - 1989',
#  'Converted sessions/Session 72 - 2017',
#  'Converted sessions/Session 65 - 2010',
#  'Converted sessions/Session 33 - 1978',
#  'Converted sessions/Session 38 - 1983',
#  'Converted sessions/Session 70 - 2015',
#  'Converted sessions/Session 43 - 1988',
#  'Converted sessions/Session 30 - 1975',
#  'Converted sessions/Session 31 - 1976',
#  'Converted sessions/Session 67 - 2012',
#  'Converted sessions/Session 46 - 1991',
#  'Converted sessions/Session 64 - 2009',
#  'Converted sessions/Session 51 - 1996',
#  'Converted sessions/Session 49 - 1994',
#  'Converted sessions/Session 68 - 2013',
#  'Converted sessions/Session 58 - 2003',
#  'Converted sessions/Session 41 - 1986',
#  'Converted sessions/Session 25 - 1970',
#  'Converted sessions/Session 61 - 2006',
#  'Converted sessions/Session 50 - 1995']

# %%
# creating a Dataframe to store the speeches
df = pd.DataFrame(columns={'Country','Speech','Session','Year'})

# %%
# read speeches by USA
i = 0 
# for each folder
for file in folders:
    # getting the txt file containing speech of USA    
    speech = glob.glob(file+'/USA*.txt')
    # reading the txt file
    with open(speech[0],encoding='utf8') as f:
        # reading the speech
        df.loc[i,'Speech'] = f.read()
        # extracting the year of speech
        df.loc[i,'Year'] = speech[0].split('_')[-1].split('.')[0]
        # extracting the session
        df.loc[i,'Session'] = speech[0].split('_')[-2]
        # storing the country name
        df.loc[i,'Country'] = speech[0].split('_')[0].split("/")[-1]
        # Increment counter
        i += 1

# %%
# first 5 rows of the created dataset    
df.head()
# Out:
#   Country Session  Year                                             Speech
# 0     USA      27  1972  During the past few years the world has made r...
# 1     USA      47  1992  Forty-seven years ago I was a young man of 21,...
# 2     USA      54  1999  Today, we look ahead to the\nnew millennium. A...
# 3     USA      57  2002  ﻿We meet one year and one day\nafter a terrori...
# 4     USA      56  2001  ﻿We meet in a Hall devoted to\npeace; in a cit...

# %%
# sample speech from the dataset
df['Speech'][1]
# Out:
# 'Forty-seven years ago I was a young man of 21, and, \nlike thousands of others of my generation, I had gone off to war to help keep \nfreedom alive. Forty-seven years ago this month the war was finally over, and \nI was looking forward to peace and the chance to begin my life in earnest: \n1945 marked a moment of promise, not just for me, but for all of mankind. A \ngreat struggle against dictatorship had been fought and won. Across the \nglobe, we all looked forward to a future free of war, a world where we might \nraise our children in peace and freedom, and this institution, the United \nNations, born amidst the ashes of war, embodied those hopes and dreams like no \nother. \nBut the hopes and dreams of 1945 remained unfulfilled: communist \nimperialism divided the world in two, our hopes for peace and our dreams of \nfreedom were frozen in the grip of cold war, and, instead of finding a common \nground, we found ourselves at Ground Zero. Instead of living on Churchill\'s \nThe President returned to the Chair. \n\n"broad, sunlit uplands", millions found that there was, as Arthur Koestler so \nchillingly wrote, "Darkness at Noon". Instead of uniting the nations, this \nbody became a forum for distrust and division among nations and, in a cruel \nirony, the United Nations, created to free the world of conflict, itself \nbecame conflict\'s captive. \nI too lived through those disputes; I sat where you sit, proudly so; I \nserved in this Assembly and I saw, in my time, the consequences of the cold \nwar\'s hot words on the higher missions of the United Nations. Now, 47 years \nlater, we stand at the end of another war, the cold war, and our hopes and \ndreams have awakened again. Driven by its own internal contradictions and \nbanished by the peoples\' undying thirst for freedom, imperial communism has \ncollapsed in its birthplace, and today Russia has awakened democratic, \nindependent and free; the Baltic States are free; and so too are Ukraine, \nArmenia, Belarus, Kazakhstan and the other independent States joining the \nnations of Central and Eastern Europe in freedom. \nThe fear of nuclear Armageddon between the super-Powers has vanished, and \nwe are proud to have done our part to ensure that our schoolchildren do not \nhave to practise hiding under their desks for fear of nuclear attack, as the \ngeneration before them did. I am proud also to salute the courageous leaders \nwith nuclear responsibilities Presidents Yeltsin, Kravchuk, Nazarbayev, \nShushkevich who joined me in ending the super-Power stand-off that risked \nnuclear nightmare. This is the first General Assembly session to seat you as \ntruly independent and free nations, and to you and the leaders of the other \nindependent States, I say welcome home: we are now truly united nations. \n\nWith the cold war\'s end, I believe we have a unique opportunity to go \nbeyond artificial divisions of a first, second and third world to forge \ninstead a genuine, global community of free and sovereign nations, a community \nbuilt on respect for principle, on peaceful settlement of disputes, on \nfundamental human rights and on the twin pillars of freedom: democracy and \nfree markets. Already, the United Nations, especially the Security Council, \nhas done much to fulfil its original mission and to build this global \ncommunity. \nUnited Nations leadership has been critical in resolving conflicts and \nbrokering peace the entire world over, but securing democracy and securing the \npeace in the century ahead will be no simple task. Imperial communism may \nhave been vanquished, but that does not end the challenges of our age, \nchallenges that must be overcome if we are finally to end the divisions \nbetween East and West, North and South, that fuel strife and strain and \nconflict and war. \nAs we support the historic growth of democracy around the world, I \nbelieve the community of nations and the United Nations face three critical, \ninterrelated challenges as we e ...

# %%
# function to preprocess speech
def clean(text):
    # removing paragraph numbers
    text = re.sub('[0-9]+.\t','',str(text))
    # removing new line characters
    text = re.sub('\n ','',str(text))
    text = re.sub('\n',' ',str(text))
    # removing apostrophes
    text = re.sub("'s",'',str(text))
    # removing hyphens
    text = re.sub("-",' ',str(text))
    text = re.sub("— ",'',str(text))
    # removing quotation marks
    text = re.sub('\"','',str(text))
    # removing salutations
    text = re.sub("Mr\.",'Mr',str(text))
    text = re.sub("Mrs\.",'Mrs',str(text))
    # removing any reference to outside text
    text = re.sub("[\(\[].*?[\)\]]", "", str(text))
        
    return text

# %%
# preprocessing speeches
df['Speech_clean'] = df['Speech'].apply(clean)

# %%
# first 5 rows of the dataset
df.head()
# Out:
#   Country  ...                                       Speech_clean
# 0     USA  ...  During the past few years the world has made r...
# 1     USA  ...  Forty seven years ago I was a young man of 21,...
# 2     USA  ...  Today, we look ahead to the new millennium. An...
# 3     USA  ...  ﻿We meet one year and one day after a terroris...
# 4     USA  ...  ﻿We meet in a Hall devoted to peace; in a city...
#
# [5 rows x 5 columns]

# %%
# sample cleaned speech
df['Speech_clean'][1]
# Out:
# "Forty seven years ago I was a young man of 21, and,  like thousands of others of my generation, I had gone off to war to help keep  freedom alive. Forty seven years ago this month the war was finally over, and  I was looking forward to peace and the chance to begin my life in earnest:  1945 marked a moment of promise, not just for me, but for all of mankind. A  great struggle against dictatorship had been fought and won. Across the  globe, we all looked forward to a future free of war, a world where we might  raise our children in peace and freedom, and this institution, the United  Nations, born amidst the ashes of war, embodied those hopes and dreams like no  other.  But the hopes and dreams of 1945 remained unfulfilled: communist  imperialism divided the world in two, our hopes for peace and our dreams of  freedom were frozen in the grip of cold war, and, instead of finding a common  ground, we found ourselves at Ground Zero. Instead of living on Churchill  The President returned to the Chair.   broad, sunlit uplands, millions found that there was, as Arthur Koestler so  chillingly wrote, Darkness at Noon. Instead of uniting the nations, this  body became a forum for distrust and division among nations and, in a cruel  irony, the United Nations, created to free the world of conflict, itself  became conflict captive.  I too lived through those disputes; I sat where you sit, proudly so; I  served in this Assembly and I saw, in my time, the consequences of the cold  war hot words on the higher missions of the United Nations. Now, 47 years  later, we stand at the end of another war, the cold war, and our hopes and  dreams have awakened again. Driven by its own internal contradictions and  banished by the peoples' undying thirst for freedom, imperial communism has  collapsed in its birthplace, and today Russia has awakened democratic,  independent and free; the Baltic States are free; and so too are Ukraine,  Armenia, Belarus, Kazakhstan and the other independent States joining the  nations of Central and Eastern Europe in freedom.  The fear of nuclear Armageddon between the super Powers has vanished, and  we are proud to have done our part to ensure that our schoolchildren do not  have to practise hiding under their desks for fear of nuclear attack, as the  generation before them did. I am proud also to salute the courageous leaders  with nuclear responsibilities Presidents Yeltsin, Kravchuk, Nazarbayev,  Shushkevich who joined me in ending the super Power stand off that risked  nuclear nightmare. This is the first General Assembly session to seat you as  truly independent and free nations, and to you and the leaders of the other  independent States, I say welcome home: we are now truly united nations.   With the cold war end, I believe we have a unique opportunity to go  beyond artificial divisions of a first, second and third world to forge  instead a genuine, global community of free and sovereign nations, a community  built on respect for principle, on peaceful settlement of disputes, on  fundamental human rights and on the twin pillars of freedom: democracy and  free markets. Already, the United Nations, especially the Security Council,  has done much to fulfil its original mission and to build this global  community.  United Nations leadership has been critical in resolving conflicts and  brokering peace the entire world over, but securing democracy and securing the  peace in the century ahead will be no simple task. Imperial communism may  have been vanquished, but that does not end the challenges of our age,  challenges that must be overcome if we are finally to end the divisions  between East and West, North and South, that fuel strife and strain and  conflict and war.  As we support the historic growth of democracy around the world, I  believe the community of nations and the United Nations face three critical,  interrelated challenges as we enter the twenty first century.  First, we face the political challenge of k ...

# %%
# splitting sentences
def sentences(text):
    # split sentences and questions
    text = re.split('[.?]', text)
    clean_sent = []
    for sent in text:
        clean_sent.append(sent)
    return clean_sent

# %%
# creating a new column to store the sentences
df['Sentence'] = df['Speech_clean'].apply(sentences)

# %%
# first 5 rows
df.head()
# Out:
#   Country  ...                                           Sentence
# 0     USA  ...  [During the past few years the world has made ...
# 1     USA  ...  [Forty seven years ago I was a young man of 21...
# 2     USA  ...  [Today, we look ahead to the new millennium,  ...
# 3     USA  ...  [﻿We meet one year and one day after a terrori...
# 4     USA  ...  [﻿We meet in a Hall devoted to peace; in a cit...
#
# [5 rows x 6 columns]

# %%
# sample sentence list from the dataset
df['Sentence'][1]
# Out:
# ['Forty seven years ago I was a young man of 21, and,  like thousands of others of my generation, I had gone off to war to help keep  freedom alive',
#  ' Forty seven years ago this month the war was finally over, and  I was looking forward to peace and the chance to begin my life in earnest:  1945 marked a moment of promise, not just for me, but for all of mankind',
#  ' A  great struggle against dictatorship had been fought and won',
#  ' Across the  globe, we all looked forward to a future free of war, a world where we might  raise our children in peace and freedom, and this institution, the United  Nations, born amidst the ashes of war, embodied those hopes and dreams like no  other',
#  '  But the hopes and dreams of 1945 remained unfulfilled: communist  imperialism divided the world in two, our hopes for peace and our dreams of  freedom were frozen in the grip of cold war, and, instead of finding a common  ground, we found ourselves at Ground Zero',
#  ' Instead of living on Churchill  The President returned to the Chair',
#  '   broad, sunlit uplands, millions found that there was, as Arthur Koestler so  chillingly wrote, Darkness at Noon',
#  ' Instead of uniting the nations, this  body became a forum for distrust and division among nations and, in a cruel  irony, the United Nations, created to free the world of conflict, itself  became conflict captive',
#  '  I too lived through those disputes; I sat where you sit, proudly so; I  served in this Assembly and I saw, in my time, the consequences of the cold  war hot words on the higher missions of the United Nations',
#  ' Now, 47 years  later, we stand at the end of another war, the cold war, and our hopes and  dreams have awakened again',
#  " Driven by its own internal contradictions and  banished by the peoples' undying thirst for freedom, imperial communism has  collapsed in its birthplace, and today Russia has awakened democratic,  independent and free; the Baltic States are free; and so too are Ukraine,  Armenia, Belarus, Kazakhstan and the other independent States joining the  nations of Central and Eastern Europe in freedom",
#  '  The fear of nuclear Armageddon between the super Powers has vanished, and  we are proud to have done our part to ensure that our schoolchildren do not  have to practise hiding under their desks for fear of nuclear attack, as the  generation before them did',
#  ' I am proud also to salute the courageous leaders  with nuclear responsibilities Presidents Yeltsin, Kravchuk, Nazarbayev,  Shushkevich who joined me in ending the super Power stand off that risked  nuclear nightmare',
#  ' This is the first General Assembly session to seat you as  truly independent and free nations, and to you and the leaders of the other  independent States, I say welcome home: we are now truly united nations',
#  '   With the cold war end, I believe we have a unique opportunity to go  beyond artificial divisions of a first, second and third world to forge  instead a genuine, global community of free and sovereign nations, a community  built on respect for principle, on peaceful settlement of disputes, on  fundamental human rights and on the twin pillars of freedom: democracy and  free markets',
#  ' Already, the United Nations, especially the Security Council,  has done much to fulfil its original mission and to build this global  community',
#  '  United Nations leadership has been critical in resolving conflicts and  brokering peace the entire world over, but securing democracy and securing the  peace in the century ahead will be no simple task',
#  ' Imperial communism may  have been vanquished, but that does not end the challenges of our age,  challenges that must be overcome if we are finally to end the divisions  between East and West, North and South, that fuel strife and strain and  conflict and war',
#  '  As we support the historic growth of democracy around the world, I  believe the community of nations and the United Nations face three critical,  interrelated challenges as we enter the twenty first century',
#  '  First, we face the political challenge of keeping today peace and  preventing tomorrow wars',
#  ' As we see daily in Bosnia, Somalia and Cambodia,  everywhere conflict claims innocent lives; the need for enhanced peace keeping  capabilities has never been greater; the conflicts we must deal with have  never been more intractable, the costs of conflict higher',
#  '  Second, we face the strategic challenge of the proliferation of weapons  of mass destruction, truly the fastest growing security challenge to  international peace and order',
#  '   Third, we face the common economic challenge of promoting prosperity for  all, of strengthening an open, growth oriented, free market international  economic order while safeguarding the environment',
#  '  Meeting these challenges will require us to strengthen our collective  engagement; it will require us to transform our collective institutions; and,  above all, it will require that each of us look seriously at our own  Government and how we conduct our international affairs',
#  ' We too must change  our institutions and our practices if we are to make a new world of the  promises of today, if we are to secure a twenty first century peace',
#  '  With you today I would like to discuss these three challenges:  peace keeping, proliferation and prosperity',
#  ' And I should like to use this  opportunity to begin to sketch how I believe the international community can  work together to meet these three challenges and how the United States is  changing its institutions and policies to catalyze this effort',
#  '  Let me begin with peace keeping',
#  ' The United Nations has a long and  distinguished history of peace keeping and humanitarian relief',
#  ' From Cyprus  and Lebanon, to Cambodia and Croatia, the blue beret has become a symbol of  hope amid all that hostility',
#  ' And the United Nations has long played a  central role in preventing conflicts from turning into wars, and strengthening  peace keeping capabilities can help buttress these diplomatic efforts',
#  ' But,  as much as the United Nations has done, it can do much more',
#  '  Peace keepers are stretched to the limit while the demands for their  services increase by the day',
#  ' The need for monitoring and preventive  peace keeping putting people on the ground before the fighting starts   may  become especially critical in volatile regions',
#  ' This is especially the case  because of the rapid and turbulent change that continues to shake Eastern  Europe and Eurasia',
#  ' Across the lands that once were imprisoned behind an iron  curtain, peoples are reasserting their historical identities that were frozen  in communism catacomb',
#  '  Where this is taking place in a democratic manner with tolerance and  civility and respect for fundamental human rights and freedoms, this new  democratic nationalism is all to the good',
#  ' But, unfortunately, we need only  look to the bloody battles raging in places such as the former Yugoslavia to  see the dangers of ethnic violence',
#  ' This is the greatest threat to the  democratic peace we hope to build with Eastern Europe, with Russia and  Eurasia, even more than economic deprivation',
#  ' We fully support the efforts of  the North Atlantic Treaty Organization , the Conference on Security and  Cooperation in Europe , the Western European Union , the  Commonwealth of Independent States  and other competent regional  organizations to develop peace keeping capabilities',
#  '  We are convinced, however, that enhanced United Nations capabilities are  a necessary complement to these regional efforts, not just in Europe and  Eurasia, but across the globe',
#  '  I welcome the Secretary General call for a new agenda to strengthen the  ability of the United Nations to prevent, contain and resolve conflicts across  the globe',
#  ' Today I call upon all Members to join me in taking bold steps to  advance that agenda',
#  ' I will therefore be discussing with my colleagues the  merits of a special meeting of the Security Council to discuss the  Secretary General proposals and to develop concrete responses in five key  areas',
#  '  First, robust peace keeping requires men and equipment that only Member  States can provide',
#  ' Nations should develop and train military units for  possible peace keeping operations and humanitarian relief and these forces  must be available on short notice at the request of the Security Council and  with the approval, of course, of the Governments providing it',
#  '  Secondly, if multinational units are to work together, they must train  together',
#  ' Many nations for example, Fiji, Norway, Canada and Finland have  a long history of peace keeping and we can all tap into that experience as we  train for expanded operations',
#  ' Effective multinational action will also  require coordinated command and control and inter operability of both  equipment and communications',
#  ' Multinational planning, training, field   exercises will be needed',
#  ' Those efforts should link up with regional  organizations',
#  '  Thirdly, we also need to provide adequate logistical support for  peace keeping and humanitarian operations',
#  ' Member States should designate  stockpiles of resources necessary to meet humanitarian emergencies, including  famines, floods and civil disturbances',
#  ' This will save valuable time in a  crisis',
#  '  Fourthly, we will need to develop planning, crisis management and  intelligence capabilities for peace keeping and humanitarian operations',
#  '  Fifthly, we must ensure adequate equitable financing for United Nations  and associated peace keeping efforts',
#  '  As I said, we must change our national institutions if we are to change  our international relations',
#  ' So let me assure you that the United States is  ready to do its part to strengthen world peace by strengthening international  peace keeping',
#  '  For decades, the American military has served as a stabilizing presence  around the globe',
#  ' And I want to draw on our extensive experience in winning  wars, in keeping the peace, to support United Nations peace keeping',
#  ' I have  directed the United States Secretary of Defense to place a new emphasis on  peace keeping',
#  ' Because of peace keeping growing importance as a mission for  the United States military, we will emphasize training of combat, engineering  and logistical units for the full range of peace keeping and humanitarian  activities and we will work with the United Nations to best employ our  considerable lift, logistics, communications and intelligence capabilities to  support peace keeping operations',
#  ' And we will offer our capabilities for  joint simulations and exercises to strengthen our ability to undertake joint  peace keeping operations',
#  '   There is room for all countries, large and small, and I hope all will  play a part',
#  '  Member States, as always, must retain the final decision on the use of  their troops, of course',
#  ' But we must develop our ability to coordinate  peace keeping efforts so that we can mobilize quickly when a threat to peace  arises or when people in need look to the world for help',
#  '  I have further directed the establishment of a permanent peace keeping  curriculum in United States military schools',
#  ' Training, plainly, is a key  element',
#  ' The United States is prepared to make available our bases and  facilities for multinational training and field exercises',
#  ' One such base,  nearby, with facilities is Fort Dix',
#  ' America used these bases to win the cold  war and today, with that war over, they can help build a lasting peace',
#  '  The United States is willing to provide our military expertise to the  United Nations to help the United Nations strengthen its planning and  operations for peace keeping, and we will also broaden American support for  monitoring, verification, reconnaissance and other requirements of United  Nations peace keeping or humanitarian assistance operations',
#  '  And, finally, the United States will review how we fund peace keeping and  explore new ways to ensure adequate American financial support for United  Nations peace keeping and United Nations humanitarian activities',
#  ' I do  believe that we must think differently about how we ensure and pay for our  security in this new era',
#  '  While the cold war may have ended, the super Power nuclear arms  competition, regional competition, weapons of mass destruction continue',
#  ' Over  20 countries have, or are developing, nuclear, chemical or biological weapons  and the means to deliver them',
#  ' At a time when the United States and its  former adversaries are engaged in deep, historic cuts in our nuclear arsenals,  our children and grandchildren will never forgive us if we allow new and  unstable nuclear stand offs to develop around the world',
#  '   We believe the Security Council should become a key forum for  non proliferation enforcement',
#  ' The Security Council should make clear its  intention to stem proliferation and sanction proliferators',
#  ' Reaffirming  assurances made at the time the Treaty on the Non Proliferation of Nuclear  Weapons was negotiated, I propose that the Security Council reassure the  non nuclear States that it will seek immediate action to provide assistance,  in accordance with the Charter, to any any non nuclear weapon State party to  the non proliferation Treaty that is a victim of an act of aggression or an  object of threat of aggression involving nuclear weapons',
#  '  I also call for the indefinite renewal of the nuclear non proliferation  Treaty when it is reviewed in 1995',
#  ' I believe we must explore ways we can  strengthen linkages between the suppliers clubs, the nuclear suppliers  group, the Australia Group, the missile technology control regime and United  Nations specialized agencies',
#  '  Here I would like to note the productive efforts of the United Nations  Special Commission  to dismantle the Iraqi weapons of mass destruction  programme, and the continuing good work of the International Atomic Energy  Agency ',
#  ' But as the United Nations organizations adapt to stop  proliferation, so too must every Member State change its structures to advance  our non proliferation goals',
#  '  In that spirit I want today to announce my intention to work with the  United States Congress to redirect the United States Arms Control and  Disarmament Agency  to refocus its talents on providing technical  support for non proliferation, weapons monitoring and destruction, and global  defence conversion',
#  ' Under the direction of the Secretary of State, ACDA   should be used not only in completing the traditional arms control agenda but,  just as importantly, in providing technical assistance on our new security  agenda',
#  '  Even as we work to prevent proliferation of weapons of mass destruction,  we must be realistic and guard ourselves against proliferation that is already  taking place',
#  ' Therefore, we are working towards a cooperative system for  defence against limited ballistic missile attacks',
#  ' We fully intend to have  other nations participate in this global protection system',
#  '  While expanded peace keeping capabilities and improved non proliferation  efforts will be critical for building an enduring peace, shared economic  growth is the long term foundation for a brighter future well into the next  century',
#  ' That is why I stated yesterday, during a moment of international  uncertainty, that the United States would be strongly engaged with its global  partners in building a global economic, financial and trading structure for  this new era',
#  '  At the same time, I urged that our global responsibilities lead us to  examine ways to strengthen the Group of Seven  coordination process, and  I affirmed America support for a European integration that opens markets and  enhances Europe capability to be our partner in the great challenges that we  face in this new era',
#  ' While the exact form of integration is, of course, for  Europeans to determine, we will stand by them',
#  '  Economic growth is not a zero sum process',
#  ' All of us will benefit from  the expanded trade and investment that comes from a vibrant, growing world  economy',
#  ' To ensure that the benefits of this growth are sustained and shared  by all, fair and open competition should be the fuel for the global economic   engine',
#  ' That is why the United States wants to complete the Uruguay Round of  the negotiations within the General Agreement on Tariffs and Trade  as  soon as possible, and to create a network of free trade agreements, beginning  with the North American Free Trade Agreement',
#  '  At the same time, we need to recognize that we have a shared  responsibility to foster and support the free market reforms necessary to  build growing economies and vibrant democracies in the developing world and in  the new democratic States',
#  ' This should be done by promoting the private  sector to build these new economies, not by fostering dependency with  traditional Government to Government foreign aid',
#  '  After the Second World War, foreign assistance often served as a weapon  in the cold war',
#  ' Obviously, we will still use critical foreign assistance  funds to meet legitimate security needs',
#  ' And, as our humanitarian operations  in Somalia and northern Iraq, Bosnia and the former Soviet Union will testify,  we will continue our robust humanitarian assistance efforts to help those  suffering from man made and natural disasters',
#  '  But foreign aid as we have known it needs to be transformed',
#  ' The notion  of the handout to less developed countries needs to give way to cooperation  and mutually productive economic relationships',
#  ' We know this: the more a  nation relies on the private sector and free markets, the higher its rate of  growth; the more open to trade it is, the higher its rate of growth; and the  better a country investment climate, the higher its rate of growth',
#  '  To move from what I would call aid dependency to economic partnership, we  propose to alter fundamentally the focus of United States assistance  programmes to building strong, independent economies that can become   contributors to a healthy, growing global economy',
#  ' That means that our new  emphasis should be on building economic partnerships among our private sectors  that will promote prosperity at home, and abroad also',
#  ' Working with our  Congress I will propose a top to bottom overhaul of our institutions that plan  and administer foreign assistance, drastically reducing the bureaucracy that  has built up around Government based programmes, streamlining our delivery  systems and strengthening support for private sector development and economic  reform',
#  '  The Agency for International Development , another institution born  during the cold war, needs to be fundamentally and radically overhauled',
#  '  Promoting economic security, opportunity and competitiveness will become a  primary mission of the State Department',
#  ' Our assistance efforts should not be  charity',
#  ' On the contrary, they should promote mutual prosperity',
#  ' Therefore,  using existing foreign affairs resources, I will propose creating a $1 billion  growth fund',
#  ' The fund will provide grants and credits to support United  States businesses in providing expertise, goods and services desperately  needed in countries undertaking economic restructuring',
#  '  I will also support significantly increasing the programmes of the  Export Import Bank to ensure that United States products and technology  promote investment in world wide economic growth',
#  '  The United States will work with its global partners, especially the G 7  nations, to enhance global growth at this key point in world history, as we  end one era and begin another',
#  '  None of us can afford insular policies',
#  ' Each of us must contribute,  through greater coordinated action, to building ¬£ stronger world economy',
#  '   I realize that what I have outlined today is an ambitious agenda',
#  ' But we  live in remarkable times: times when empires collapse, ideologies dissolve  and walls crumble; times when change can come so fast that we sometimes forget  how far and how fast we have progressed in achieving our hopes for a global  community of democratic nations',
#  '   And in the face of today changes, with the loss of so much that was  familiar and predictable, there is now a great temptation for people  everywhere to turn inward and to build walls around themselves walls against  trade, walls against people, walls against ideas and investment, walls against  anything at all that appears new and different',
#  '  As the Berlin Wall fell, these walls too must fall',
#  ' They must fall  because we cannot separate our fate from that of others',
#  ' Our peace is so  interconnected, our security so intertwined, our prosperity so interdependent,  that to turn inward and retreat from the world is to invite disaster and  defeat',
#  '  At the threshold of a new century we can truly say a more peaceful, more  secure, more prosperous future beckons to us',
#  ' For the sake of our children  and our grandchildren, for the sake of those who perished during the cold war  and for the sake of every man, woman and child who kept freedom flame alive  even during the darkest noon, let us pledge ourselves to make that future  real, and let us pledge ourselves to fulfil the promise of a truly United  Nations',
#  '  Thank you and may God bless you all',
#  '  ']

# %%
# create a dataframe containing sentences
df2 = pd.DataFrame(columns=['Sentence','Year','Len'])

row_list = []

# for each speech
for i in range(len(df)):
    # for each sentence
    for sent in df.loc[i,'Sentence']:
    
        # calculating the word count in a sentence
        wordcount = len(sent.split())
        # extracting the year of speech
        year = df.loc[i,'Year']

        dict1 = {'Year':year,'Sentence':sent,'Len':wordcount}
        row_list.append(dict1)
    
df2 = pd.DataFrame(row_list)

# %%
# first 5 rows
df2.head()
# Out:
#    Year                                           Sentence  Len
# 0  1972  During the past few years the world has made r...   29
# 1  1972   In 1972 alone, the United States and the Sovi...   49
# 2  1972   The Soviet Union and the United States have a...   29
# 3  1972   The United States and the People Republic of ...   56
# 4  1972   The United Kingdom, France, the Soviet Union ...   29

# %%
# shape of the dataset
df2.shape
# Out:
# (8948, 3)

# %% [markdown]
# Sample sentences from dataset:
#
# 1.  For that reason, **President Reagan**, in his speech to this body last year, proposed that the United States and the Soviet Union exchange visits of experts at test sites to measure directly the yields of nuclear weapon test
# 2.  **President Reagan** has directed our scientists and engineers to examine, in the light of new technologies and fully in accord with the Anti Ballistic Missile Treaty   the feasibility of defense against ballistic missile attack
# 3.   **President Reagan** approach to foreign policy is  grounded squarely on standards drawn from the  pragmatic American experience
# 4.  Let me start by joining the **President of Brazil** in conveying to the people and Government of Mexico our deep sympathy over the devastation wrought by earthquakes and our solidarity with them as they work to recover and rebuild

# %% [markdown]
# ## 3. Rule 1 - Extracting the sentences with President's mention

# %%
# importing spacy and its matcher function
import spacy
from spacy.matcher import Matcher

# load english language model
nlp = spacy.load('en_core_web_sm',disable=['ner','textcat'])

# %%
# function to find sentences mentioning president
def find_names(text):
    
    names = []
    
    # spacy doc
    doc = nlp(text)
    
    # pattern
    pattern = [{'LOWER':'president'},
              {'POS':'ADP','OP':'?'},
              {'POS':'PROPN'}]
                
    # Matcher class object 
    matcher = Matcher(nlp.vocab) 
    matcher.add("names", None, pattern) 

    matches = matcher(doc)

    # finding patterns in the text
    for i in range(0,len(matches)):
        
        # match: id, start, end
        token = doc[matches[i][1]:matches[i][2]]
        # append token to list
        names.append(str(token))
            
    return names

# %%
# extracting sentences with president's mentions
extracted_sentences = []
for i in range(df2.shape[0]):
    extracted_sentences.append(find_names(df2['Sentence'][i]))

# storing the extracted sentences in the dataframe
df2['President_Names'] = extracted_sentences

# %%
# first 5 rows
df2.head()
# Out:
#    Year                                           Sentence  Len President_Names
# 0  1972  During the past few years the world has made r...   29              []
# 1  1972   In 1972 alone, the United States and the Sovi...   49              []
# 2  1972   The Soviet Union and the United States have a...   29              []
# 3  1972   The United States and the People Republic of ...   56              []
# 4  1972   The United Kingdom, France, the Soviet Union ...   29              []

# %%
# extracting only the non-null outputs 
mention = []
for i in range(df2.shape[0]):
    if df2['President_Names'][i] != []:
        mention.append(df2['President_Names'][i])

mention
# Out:
# [['President Nixon'],
#  ['President Nixon'],
#  ['President Nixon'],
#  ['President Nixon'],
#  ['President Yeltsin'],
#  ['President Mugabe'],
#  ['President Carter', 'President in January'],
#  ['President Carter'],
#  ['President Carter'],
#  ['President de'],
#  ['President Kennedy'],
#  ['President Roosevelt'],
#  ['President Al'],
#  ['President Gore'],
#  ['President C1inton'],
#  ['President Clinton'],
#  ['President Ford'],
#  ['President Ford'],
#  ['President Ford'],
#  ['President Reagan'],
#  ['President of Brazil'],
#  ['President Sarney'],
#  ['President Duarte'],
#  ['president in November'],
#  ['President Reagan'],
#  ['President Duarte'],
#  ['President Reagan'],
#  ['President Reagan'],
#  ['President Reagan'],
#  ['President Reagan'],
#  ['President Reagan'],
#  ['President Reagan'],
#  ['President Carter'],
#  ['President Mondaleat'],
#  ['President Bush'],
#  ['President Bush'],
#  ['President Bush'],
#  ['President Ping'],
#  ['President Eliasson'],
#  ['President Bush'],
#  ['President Nixon'],
#  ['President Nixon'],
#  ['President Harry'],
#  ['President Sarney'],
#  ['President of Iran'],
#  ['President Nixon'],
#  ['President Nixon'],
#  ['President of Mexico'],
#  ['President Reagan'],
#  ['President Reagan'],
#  ['President Reagan'],
#  ['President Reagan'],
#  ['President Reagan'],
#  ['President Reagan'],
#  ['President Reagan'],
#  ['President Reagan'],
#  ['President Moon', 'President Xi'],
#  ['President Moon'],
#  ['President Xi'],
#  ['President Monroe'],
#  ['President Franklin'],
#  ['President Saleh'],
#  ['President Truman'],
#  ['President Kennedy'],
#  ['President Abraham'],
#  ['President Truman'],
#  ['President Truman'],
#  ['President Abbas'],
#  ['President in Colombia'],
#  ['President Carter'],
#  ['President Carter'],
#  ['President Carter'],
#  ['President Dwight'],
#  ['President Ford'],
#  ['President Ford'],
#  ['President Ford'],
#  ['President of Lebanon'],
#  ['President Ford'],
#  ['President in Somalia'],
#  ['President Abbas'],
#  ['President Kennedy'],
#  ['President Yeltsin'],
#  ['President Kennedy'],
#  ['President Kennedy'],
#  ['President Menem'],
#  ['President Aristide'],
#  ['President Aristide'],
#  ['President Putin'],
#  ['President Rouhani'],
#  ['President Rouhani'],
#  ['President Rouhani'],
#  ['President Nixon'],
#  ['President Nasser'],
#  ['President Nixon'],
#  ['President Nixon'],
#  ['President Nixon'],
#  ['President Nixon'],
#  ['President Talabani'],
#  ['President Abbas'],
#  ['President Abbas'],
#  ['President Clinton'],
#  ['President Clinton'],
#  ['President Yeltsin'],
#  ['President Clinton'],
#  ['President Clinton'],
#  ['President Clinton'],
#  ['President Clinton']]

# %%
# extracting only those sentences which has president's mention
sentences_president = []
for i in range(df2.shape[0]):
    if df2['President_Names'][i] != []:
        sentences_president.append(df2['Sentence'][i])

sentences_president
# Out:
# [' As President Nixon said to this General Assembly in 1969, our objective is ',
#  ' President Nixon has proposed a cease fire in all of IndoChina under international supervision, an exchange of prisoners of war, and a total withdrawal of United States forces',
#  ' President Nixon has also pledged a major effort to assist both VietNamese States in post war reconstruction',
#  " As President Nixon said last week, “Every Government which wants to move against narcotics should know that it can count on our country for our wholehearted support and assistance in doing so'",
#  ' President Yeltsin and I agreed in June, even as we await Russian ratification of START II, to begin talks on a START III treaty that will cut our cold  war arsenals by 80 per cent from their height',
#  ' This week the Security Council will hold an unprecedented ministerial meeting on African security, which our Secretary of State is proud to chair, and which President Mugabe, Chairman of the Organization of African Unity, will address',
#  ' President Carter voiced this basic commitment when lie was sworn in as President in January 1977',
#  ' First, it is President Carter intention to move forward as speedily as possible towards ratification of the SALT II Treaty',
#  ' In recognition of the human need implicit in this worldwide wave of refugees, President Carter has made known the intention of the United States to accept an additional 217,000 refugees over the next year',
#  ' We see Nelson Mandela stand side by side with President de Klerk proclaiming a date for South Africa’s first non racial elections',
#  ' Thirty two years ago President Kennedy warned this Assembly that humanity lived under a nuclear sword of Damocles that hung by the slenderest of threads',
#  ' But I agree with President Roosevelt, who once said: The democratic aspiration is no mere recent phase of human history',
#  ' Here in the United States, Vice President Al Gore and I have launched an effort literally to reinvent how our Government operates',
#  ' During the course of our campaign in the United States last year, Vice President Gore and I promised the American people major changes in our nation’s policy towards the global environment',
#  'I am honoured to address the Assembly on behalf of the United States and to reinforce the eloquent message President C1inton conveyed during last week Millennium Summit',
#  ' As President Clinton said last week, we need to ensure that United Nations peacekeepers can be deployed with the right training and equipment and the right rules of engagement so they can achieve, not merely attempt, their missions',
#  ' Last week before this Assembly  President Ford dedicated our country to a cooperative,, open approach to build a more secure and more prosperous world',
#  ' President Ford has asked me to reaffirm today that we are determined to press forward with these efforts',
#  ' Last week President Ford called upon the oil producers to join with consumers in defining a strategy which will meet the world longterm need for both energy and food at reasonable prices; he set forth the principles which should guide such a policy; and he announced to this Assembly America determination to meet our responsibilities to help alleviate another grim reality world hunger',
#  ' In October President Reagan will go to the meeting in Cancun',
#  'Let me start by joining the President of Brazil in conveying to the people and Government of Mexico our deep sympathy over the devastation wrought by earthquakes and our solidarity with them as they work to recover and rebuild',
#  ' One area where the future has brightened in the past five years as the aspirations of the people to democracy have been met in country after country is Latin America   as President Sarney just said so eloquently',
#  ' In Central America, El Salvador, under the courageous leadership of President Duarte, has shown that democracy can take root and thrive even in the most difficult terrain',
#  ' Among El Salvador neighbors, Costa Rica has long been the region beacon of representative government; Honduras is about to replace one freely elected government with another; and Guatemala is about to join them as a democratic nation with the election of a president in November',
#  ' These developments should enhance regional co operation for economic development, which the United States supports through our Caribbean Basin initiative and President Reagan initiative for peace, development and democracy',
#  ' In El Salvador, President Duarte, true to his pledge to the Assembly last year, has pursued a dialog with the guerrilla opposition',
#  ' The United States is committed and engaged in support of those efforts, in accordance with President Reagan initiative of three years ago',
#  ' In this spirit, President Reagan last June decided to continue our policy of taking no action that would undercut the limits of previous agreements, to the extent the Soviet Union shows comparable restraint',
#  ' For that reason, President Reagan, in his speech to this body last year, proposed that the United States and the Soviet Union exchange visits of experts at test sites to measure directly the yields of nuclear weapon test',
#  ' President Reagan has directed our scientists and engineers to examine, in the light of new technologies and fully in accord with the Anti Ballistic Missile Treaty   the feasibility of defense against ballistic missile attack',
#  ' President Reagan looks forward to his meeting with General Secretary Gorbachev in November',
#  ' As President Reagan is saying today in a major speech, The freer the flow of world trade, the stronger the tides for human progress and peace among nations',
#  ' President Carter has committed the United States not to import more than 8',
#  ' The proposal made by Vice President Mondaleat the Geneva Meeting for a refugee resettlement fund reflects our belief that the international community should deal on a global basis with a global and grave refugee crisis',
#  ' On behalf of President Bush and all of the American people, welcome to New York City',
#  ' And, as President Bush said on Wednesday, the United States is prepared to take new action to accelerate this progress: we will eliminate all tariffs and subsidies that distort free trade as other nations do the same',
#  ' To advance this common purpose, in 9  2004 President Bush proposed the creation of a democracy fund',
#  ' I want to thank former General Assembly President Ping for his tireless hard work',
#  ' Our challenge now, under President Eliasson’s leadership, is to enact the vital reforms that will make the United Nations more accountable to its Members, more suited to new challenges and more faithful to its founding purposes',
#  ' As President Bush said on Wednesday , the United Nations must stand for integrity and live by the high standards it sets for others',
#  ' Two years ago President Nixon pledged to the General Assembly that the United States was determined to limit, and then reverse, the build up of strategic arms',
#  ' Our views on such a final peace settlement remain those expressed in President Nixon foreign policy report earlier this year and in my statement of 9 December 1969, Both sides to the conflict are committed to the fundamental and reciprocal principles to which the Jarring mission is dedicated: living in peace with each other and withdrawal from territories occupied in the 1967 conflict as set forth in Security Council resolution 242 ',
#  '  In the final days of the San Francisco Conference,  the delegates negotiating the United Nations Charter  received a visit from President Harry Truman',
#  ' President Sarney of Brazil spoke for many others when he said that Private initiative is the engine of economic Development',
#  ' In that regard, I know that the President of Iran will be addressing representatives tomorrow',
#  ' That President Nixon should ask me as my first official act to speak here for the United States reaffirms the importance that my country attaches to the values and the ideals of the United Nations',
#  ' President Nixon has met with the leaders of that great nation; we have agreed to a historic communique  that honestly sets forth both our differences and our common principles; and we have each opened a liaison office in the capital of the other',
#  ' In this spirit, the United States is willing to examine seriously the proposal by the distinguished President of Mexico for a charter of the economic rights and duties of States',
#  '  President Reagan approach to foreign policy is  grounded squarely on standards drawn from the  pragmatic American experience',
#  ' On this foundation, President Reagan  ideas and the structure of his foreign policy are  so straight forward that those of us enmeshed in  day to day details may easily lose sight of them',
#  ' To describe conditions as we see them  as I do today and as President Reagan has over  the course of his presidency, is not to seek  confrontation—far from it',
#  ' President Reagan has instituted a bold  pro¬gram to get the American economy moving',
#  ' On 1 September President Reagan  challenged the parties to the Arab Israeli  conflict to make a fresh start on the road to  peace in the Middle East',
#  ' The road will not be easy, but in his  statement President Reagan made a number of  proposals which, for those who are willing to  join the effort, make the journey safer and  easier',
#  ' I call on all concerned to accept  President Reagan challenge and hasten the  realization of true peace in the Middle East, In addition to the imperative need to  resolve regional problems, there is an equally  significant global imperative: to halt, and  reverse, the global arms build¬up',
#  ' With this goal in mind, President Reagan  has initiated a comprehensive program for  negotiated arms reductions',
#  ' I would also like to extend special thanks to President Moon of South Korea, Prime Minister Abe of Japan and President Xi of China',
#  ' And just yesterday, I stood with President Moon to announce the successful completion of the brand new United States Korea trade deal',
#  ' I have great respect and affection for my friend President Xi, but I have made it clear that our trade imbalance is just not acceptable',
#  ' It has been the formal policy of our country since President Monroe to reject the interference of foreign nations in this hemisphere and in our own affairs',
#  ' No American did more to pursue that objective  than President Franklin Roosevelt',
#  ' We  must work with Yemen’s neighbours and our partners  around the world to seek a path that allows for a  peaceful transition of power from President Saleh, and  a movement to free and fair elections as soon as  possible',
#  ' When the cornerstone of this very building was  put in place, President Truman came here to New York  and said, “The United Nations is essentially an  expression of the moral nature of man’s aspirations”  the moral nature of man’s aspirations',
#  ' Speaking before the Assembly,  President Kennedy put it well:  “Terror is not a new weapon',
#  ' There is a painting that hangs on the wall of my office in the White House which pictures President Abraham Lincoln and his generals meeting near the end of a war that remains the bloodiest in the history of my country',
#  ' As President Truman said in his message to Congress at that time, “Our support of European recovery is in full accord with our support of the United Nations”',
#  ' If the Organization is to have any hope of successfully confronting the challenges before us, it will depend, as President Truman said some 70 years ago, on the independent strength of its Members',
#  '  President Abbas said, “We will spare no effort and we  will work diligently and tirelessly to ensure these  negotiations achieve their cause”',
#  ' And even as some  Governments roll back reform, we also celebrate the  courage of a President in Colombia who willingly  stepped aside, or the promise of a new constitution in  Kenya',
#  ' In his address before Congress on 18 September  President Carter reviewed the main elements of the Camp David agreements',
#  ' As President Carter stated in his address to Congress, the United States is irrevocably committed to bringing about a satisfactory solution to the problem of the Palestinian refugees',
#  ' President Carter made clear in his address to the joint session of Congress following the Camp David summit meetings, and again yesterday, his determination to spare no effort to assist in finding a solution to the Lebanese tragedy',
#  ' In 1956 President Dwight Eisenhower made an observation on weapons and deterrence in a letter to a publisher',
#  ' President Ford plans to visit the People Republic of China later this year to confirm the vitality of our relationship and to advance the ties between us on the basis of the strict implementation of the Shanghai Communique',
#  ' President Ford has stated that we will not accept stalemate or stagnation in the Middle East',
#  ' I have just been to Africa, at President Ford request, to see what the United States could do to help the peoples of that continent achieve their aspirations to freedom and justice',
#  ' All Members of the United Nations, and all the conflicting parties in Lebanon, have an obligation to support the efforts of the new President of Lebanon to restore peace and to turn energies to rebuilding the nation',
#  ' In the near future President Ford will announce a comprehensive American program for international action on non proliferation that reconciles global aspirations for assured nuclear supply with global requirements for nuclear control',
#  ' Over the past year, we have seen peaceful transitions of power in Malawi and Senegal and a new President in Somalia',
#  ' Yesterday I had a  constructive meeting with Prime Minister Netanyahu  and President Abbas',
#  ' I did so, with some pride, with this pen, for this pen is the very one that President Kennedy used to help bring the limited test ban Treaty to life 33 years ago',
#  ' When Russia ratifies START II, President Yeltsin and I are all ready to discuss the possibilities of further cuts, as well as limiting and monitoring nuclear warheads and materials',
#  ' Thirty three years ago, at the height of the cold war, President Kennedy spoke at American University in Washington',
#  ' President Kennedy’s vision exceeded the possibilities of his time, but his words speak to us still',
#  ' Let me suggest that it is time for the members of the Assembly to consider seriously President Menem’s suggestion for the creation of a civilian rapid response capability for humanitarian crises',
#  ' President Aristide will return',
#  ' In the spirit of reconciliation and reconstruction, President Aristide yesterday called for the immediate easing of sanctions so that the work of rebuilding can begin immediately',
#  ' However, as I have discussed  with President Putin for over a year, most recently in  St',
#  '  Since I took office, I have made it clear, in letters  to the Supreme Leader in Iran and, more recently, to  President Rouhani, that America prefers to resolve its  concerns over Iran’s nuclear programme peacefully,  although we are determined to prevent Iran from  developing a nuclear weapon',
#  ' We are encouraged by the  fact that President Rouhani received from the Iranian  people a mandate to pursue a more moderate course',
#  '  Given President Rouhani’s stated commitment to reach  an agreement, I am directing John Kerry to pursue this  effort with the Iranian Government, in close cooperation  with the European Union, the United Kingdom, France,  Germany, Russia and China',
#  ' As President Nixon said in this Assembly a year ago: ',
#  ' While recent developments in the area, including the tragic death of President Nasser, have cast a shadow over the high hopes of just a few weeks ago that a beginning toward that goal had been made, those hopes have not been extinguished',
#  ' As President Nixon pointed out in this forum a year ago, this issue involves the interests of',
#  " President Nixon, in a series of policy decisions and especially in his recent announcement on the new focus of United States economic assistance, has made clear our intention: \tTo reverse the downward trend in United States development assistance; \tTo increase substantially United States contributions to multilateral development institutions including the World Bank, the International Development Association, the regional development banks and the United Nations Development program so that, as the capabilities of these institutions increase, we may be able to channel through them most of our official development assistance; \tFurther to encourage the efforts of donor nations to untie their bilateral aid to developing countries from the obligation to import products of the donor country;  To bring United States science and technology more effectively to bear on the problems of development, and for this purpose to create a new United States International Development Institute;  To take new steps to stimulate American private investment in developing countries within the framework of the developing countries' plans",
#  ' Last May President Nixon, in a farreaching announcement concerning the oceans, proposed that an international regime be established by treaty for the exploitation of seabed resources beyond the depth of 200 meters',
#  ' With that in mind President Nixon, in his address to this Assembly a year ago , pledged the enthusiastic support of the United States for Iran proposal to establish an international volunteer service corps , to work in the cause of development and to be recruited on an individual basis from the people, principally young people, of many countries',
#  ' Now Iraq’s seat is held by a democratic  Government that embodies the aspirations of the Iraqi  people, represented today by President Talabani',
#  ' President Abbas is committed to peace and to his  people’s aspirations for a State of their own',
#  ' Prime  Minister Olmert is committed to peace, and has said he  intends to meet with President Abbas to make real  progress on the outstanding issues between them',
#  ' As President Clinton said in San Francisco in June, the “new forces of integration carry within them the seeds of disintegration and destruction”',
#  ' As President Clinton announced last month, the United States is committed to a true zero yield test ban',
#  ' As part of this process, President Yeltsin will host a nuclear safety and security summit in Moscow next spring',
#  ' President Clinton has urged the United States Senate to act promptly on its ratification, and to stop holding the START II Treaty and the Chemical Weapons Convention hostage to unrelated issues',
#  ' At last year’s session of the General Assembly, President Clinton proposed, and the Assembly approved, the eventual elimination of anti personnel mines',
#  ' 12   Two years ago, President Clinton called on the international community to devise a true international system governing the transfer of conventional weapons and sensitive dual use technologies',
#  ' Last January President Clinton issued an Executive Order prohibiting financial transactions with terrorist groups and individuals that threaten the Middle East peace process']

# %%
# number of sentences containing president's mention
len(sentences_president)
# Out:
# 107

# %%
# sample sentences with president's mention
sentences_president[1]
# Out:
# ' President Nixon has proposed a cease fire in all of IndoChina under international supervision, an exchange of prisoners of war, and a total withdrawal of United States forces'

# %%
# sample sentences with president's mention
sentences_president[10]
# Out:
# ' Thirty two years ago President Kennedy warned this Assembly that humanity lived under a nuclear sword of Damocles that hung by the slenderest of threads'

# %% [markdown]
# Sample sentences from dataset:
# 1. The United States will continue its strong efforts to advance **the United Nations plan** for Namibia
# 2. The United States and Italy have proposed **a Global Peace Operations Initiative**
# 3. For 35 years, **the North Atlantic alliance** has guaranteed the peace in Europe

# %% [markdown]
# ## 4. Rule 2 - Extracting the mentions of initiatives

# %%
# to check if keyswords like 'programs','schemes', etc. are present in sentences

def prog_sent(text):
    
    patterns = [r'\b(?i)'+'plan'+r'\b',
               r'\b(?i)'+'programme'+r'\b',
               r'\b(?i)'+'scheme'+r'\b',
               r'\b(?i)'+'campaign'+r'\b',
               r'\b(?i)'+'initiative'+r'\b',
               r'\b(?i)'+'conference'+r'\b',
               r'\b(?i)'+'agreement'+r'\b',
               r'\b(?i)'+'alliance'+r'\b']

    output = []
    flag = 0
    for pat in patterns:
        if re.search(pat, text) != None:
            flag = 1
            break
    return flag 

# apply function
df2['Check_Schemes'] = df2['Sentence'].apply(prog_sent)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: Flags not at the start of the expression '\\b(?i)plan\\b'
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: Flags not at the start of the expression '\\b(?i)programme\\b'
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: Flags not at the start of the expression '\\b(?i)scheme\\b'
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: Flags not at the start of the expression '\\b(?i)campaign\\b'
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: Flags not at the start of the expression '\\b(?i)initiative\\b'
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: Flags not at the start of the expression '\\b(?i)conference\\b'
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: Flags not at the start of the expression '\\b(?i)agreement\\b'
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: Flags not at the start of the expression '\\b(?i)alliance\\b'

# %%
# first 5 rows
df2.head()
# Out:
#    Year  ... Check_Schemes
# 0  1972  ...             0
# 1  1972  ...             0
# 2  1972  ...             0
# 3  1972  ...             0
# 4  1972  ...             0
#
# [5 rows x 5 columns]

# %%
# to extract initiatives using pattern matching
def all_schemes(text,check):
    
    schemes = []
    
    doc = nlp(text)
    
    # initiatives
    prog_list = ['programme','scheme',
                 'initiative','campaign',
                 'agreement','conference',
                 'alliance','plan']
    
    # pattern to match initiatives names 
    pattern = [{'POS':'DET'},
               {'POS':'PROPN','DEP':'compound'},
               {'POS':'PROPN','DEP':'compound'},
               {'POS':'PROPN','OP':'?'},
               {'POS':'PROPN','OP':'?'},
               {'POS':'PROPN','OP':'?'},
               {'LOWER':{'IN':prog_list},'OP':'+'}
              ]
    
    if check == 0:
        # return blank list
        return schemes

    # Matcher class object 
    matcher = Matcher(nlp.vocab) 
    matcher.add("matching", None, pattern) 
    matches = matcher(doc)

    for i in range(0,len(matches)):
        
        # match: id, start, end
        start, end = matches[i][1], matches[i][2]
        
        if doc[start].pos_=='DET':
            start = start+1
        
        # matched string
        span = str(doc[start:end])
        
        if (len(schemes)!=0) and (schemes[-1] in span):
            schemes[-1] = span
        else:
            schemes.append(span)
        
    return schemes

# apply function
df2['Schemes1'] = df2.apply(lambda x:all_schemes(x.Sentence,x.Check_Schemes),axis=1)

# %%
# first 5 rows
df2.head()
# Out:
#    Year  ... Schemes1
# 0  1972  ...       []
# 1  1972  ...       []
# 2  1972  ...       []
# 3  1972  ...       []
# 4  1972  ...       []
#
# [5 rows x 6 columns]

# %%
# extracting only the non-null outputs 
mention = []
for i in range(df2.shape[0]):
    if df2['Schemes1'][i] != []:
        mention.append(df2['Schemes1'][i])

mention
# Out:
# [['North American Free Trade Agreement'],
#  ['African Crisis Response Initiative'],
#  ['United Nations plan'],
#  ['United Nations plan'],
#  ['San Francisco Conference'],
#  ['World Food Conference'],
#  ['World Population Conference', 'World Food Conference'],
#  ['San Francisco Conference'],
#  ['Caribbean Basin initiative'],
#  ['Third Review Conference'],
#  ['Second Review Conference'],
#  ['United Nations Conference'],
#  ['World Bank programme'],
#  ['Suez Canal agreement'],
#  ['San Francisco Conference'],
#  ['Caribbean Basin Initiative'],
#  ['North Atlantic alliance'],
#  ['Geneva Peace Conference'],
#  ['Good Friday Agreement'],
#  ['United Nations Development Programme', 'World Food Programme'],
#  ['Global Peace Operations Initiative'],
#  ['San Francisco Conference'],
#  ['Women Entrepreneurs Finance Initiative'],
#  ['Arab Peace Initiative'],
#  ['Bonn Economic Summit Conference'],
#  ['Bonn Economic Summit Conference'],
#  ['World Food Conference'],
#  ['World Food Conference'],
#  ['United Nations Conference'],
#  ['Third United Nations Conference'],
#  ['Geneva Peace Conference'],
#  ['Comprehensive Peace Agreement'],
#  ['North American Free Trade Agreement'],
#  ['World Food Programme'],
#  ['Proliferation Security Initiative'],
#  ['Proliferation Security Initiative'],
#  ['United States initiative'],
#  ['United Nations Conference'],
#  ['United Nations Conference'],
#  ['United Nations International Drug Control Programme']]

# %%
# extracting sentences which mentions some initiatives
initiatives = []
for i in range(df2.shape[0]):
    if df2['Schemes1'][i] != []:
        initiatives.append(df2['Sentence'][i])

initiatives
# Out:
# [' That is why the United States wants to complete the Uruguay Round of  the negotiations within the General Agreement on Tariffs and Trade  as  soon as possible, and to create a network of free trade agreements, beginning  with the North American Free Trade Agreement',
#  ' It is why we are working with friends in Africa to build the African Crisis Response Initiative, which has trained more than 4,000 peacekeepers from six countries',
#  ' The United States will continue its strong efforts to advance the United Nations plan for Namibia',
#  ' I am convinced that the United Nations plan would be implemented fairly',
#  ' Like most of the people in the world today, I was not even alive during the convulsive world war that convinced humankind of the need for this Organization, nor during the San Francisco Conference that led to its birth',
#  ' The United States is prepared to join with all nations at the World Food Conference in Rome to launch the truly massive effort which is required',
#  ' The United States considers the World Population Conference, held last month, the World Food Conference to be held a month from now and the continuing Third United Nations Conference on the Law of the Sea of fundamental importance to our common future',
#  ' At the time of the San Francisco Conference in 1945, most of the nations represented in this hall today were not independent States but possessions   colonies of European empires',
#  ' These developments should enhance regional co operation for economic development, which the United States supports through our Caribbean Basin initiative and President Reagan initiative for peace, development and democracy',
#  ' The United States remains committed to all the goals of the Treaty, whose Third Review Conference just concluded successfully in Geneva',
#  ' The Second Review Conference of the Parties to the Treaty on the Non  Proliferation of Nuclear Weapons, to be held next year, will be a critical time for taking stock—and for redoubling our efforts to make progress on this urgent international priority',
#  ' This Institute will work for the goals set by the United Nations Conference on Science and Technology for Development',
#  ' We are supporting the expansion of the World Bank programme for the exploration and development of mineral fuels',
#  ' A fair approach should be founded on two basic principles:  That a Suez Canal agreement is merely a step towards complete and full implementation of resolution 242  within a reasonable period of time, and not an end in itself that has to be clearly established in any agreement; also  That neither side can realistically expect \\to achieve, as part of an interim agreement, complete agreement on the terms and conditions of an over all settlement  if it could, there would be no necessity for an interim agreement',
#  '  In the final days of the San Francisco Conference,  the delegates negotiating the United Nations Charter  received a visit from President Harry Truman',
#  '  The Caribbean Basin Initiative establishes the  crucial bond between economic development and  economic freedom',
#  ' For 35 years, the North Atlantic alliance has guaranteed the peace in Europe',
#  ' We are staying in close contact with the Soviet Union, with which we share responsibility for reconvening the Geneva Peace Conference on the Middle East',
#  ' The glimpse of growing prosperity in Northern Ireland was a crucial factor in the Good Friday Agreement',
#  ' We will continue our strong support for the United Nations Development Programme, the Office of the United Nations High Commissioner for Human Rights and the Office of United Nations High Commissioner for Refugees, the United Nations Children’s Fund, the World Bank and the World Food Programme',
#  ' The United States and Italy have proposed a Global Peace Operations Initiative',
#  ' One delegate to the San Francisco Conference,  which led to the creation of the United Nations, put it  well: “Many people have talked as if all we had to do  to get peace was to say loudly and frequently that  we loved peace and hated war',
#  ' We have invested in better health and opportunity all over the world through programmes like the President’s Emergency Plan for AIDS Relief, the President’s Malaria Initiative, the Global Health Security Agenda, the Global Fund to End Modern Slavery, and the Women Entrepreneurs Finance Initiative, which is part of our commitment to empowering women all across the globe',
#  ' Those who have  signed on to the Arab Peace Initiative should seize this  opportunity to make it real by taking tangible steps  towards the normalization that it promises Israel',
#  ' The Bonn Economic Summit Conference this year made clear that we must intensify our efforts in this area',
#  ' Substantive discussions in the Committee had an important impact on the Ministerial Meeting of the Organization for Economic Co operation and Development, held on 14 and 15 June, and on the Bonn Economic Summit Conference',
#  ' Four years have now passed since the World Food Conference, where we agreed on measures we must take for the future',
#  ' We intend to maintain our food aid level at a fair share of the target set at the World Food Conference',
#  ' We hope that the United Nations Conference on Science and Technology for Development, to be held next year in Vienna, will focus attention on how all countries can contribute their knowledge to global development',
#  ' Last month at Montreal I set forth our approach to this negotiation and urged that next year session of the Third United Nations Conference on the Law of the Sea move matters to a rapid and successful conclusion',
#  ' The Geneva Peace Conference on the Middle East met in 1973 under its aegis, and the implementation of subsequent agreements has been negotiated in its working groups',
#  '  We will pursue a lasting peace in Sudan, through  support for the people of Darfur and the implementation  of the Comprehensive Peace Agreement, so that we  secure the peace that the Sudanese people deserve',
#  ' Though still in its infancy, the North American Free Trade Agreement has dramatically increased trade between the United States and Mexico and has produced in the United States alone an estimated 200,000 new jobs',
#  ' Iraq food distribution system is operational, delivering nearly a half million tons of food per month, thanks to the skill and expertise of the World Food Programme',
#  ' Through our Proliferation Security Initiative, eleven nations are preparing to search planes, ships, trains and trucks carrying suspect cargo and to seize weapons or missile shipments that raise proliferation concerns',
#  ' These nations have agreed on a set of interdiction principles consistent with current legal authorities, and we are working to expand the Proliferation Security Initiative to other countries',
#  ' Security Council resolution 242  stands as a beacon pointing the way to peace, and the parties concerned, in accepting the United States initiative of June, have committed themselves to carry out that resolution in all its parts',
#  ' Already the plans for the United Nations Conference on the Human Environment in 1972 have begun to take shape and have helped to focus the attention of United Nations Member Governments on this worldwide challenge; but we should not wait for the Stockholm Conference before launching necessary initiatives',
#  ' We should ensure that the functions of the United Nations Conference on Trade and Development do not duplicate those of the new World Trade Organization , and we should adopt a moratorium on big United Nations conferences once the present series is completed, concentrating instead on meeting the commitments of those conferences that we have already held',
#  ' We are providing similar help bilaterally, and through the United Nations International Drug Control Programme, to those countries whose laws are challenged by international drug cartels']

# %%
# number of sentences which mentions some initiatives
len(initiatives)
# Out:
# 40

# %%
# sample sentences containing initiatives
initiatives[0]
# Out:
# ' That is why the United States wants to complete the Uruguay Round of  the negotiations within the General Agreement on Tariffs and Trade  as  soon as possible, and to create a network of free trade agreements, beginning  with the North American Free Trade Agreement'

# %%
# sample sentences containing initiatives
initiatives[3]
# Out:
# ' I am convinced that the United Nations plan would be implemented fairly'

# %% [markdown]
# ## 5. Rule 3 - Relation Extraction part 1

# %% [markdown]
# Sample sentences from dataset:
# 1.   The United **States** will **support** these **principles**
# 2.    Yet these very small **entities need** more than most the **assistance** that the United Nations system can provide
# 3.  I have proposed to Congress that the United **States provide** additional **funding** for our work in Iraq, the greatest financial commitment of its kind since the Marshall Plan
#
# ![image.png](data:image/png;base64,...)

# %%
# function for rule 3: noun(subject), verb, noun(object)
def rule3(text):
    
    doc = nlp(text)
    
    sent = []
    
    for token in doc:
        
        # if the token is a verb
        if (token.pos_=='VERB'):
            
            phrase =''
            
            # only extract noun or pronoun subjects
            for sub_tok in token.lefts:
                
                if (sub_tok.dep_ in ['nsubj','nsubjpass']) and (sub_tok.pos_ in ['NOUN','PROPN','PRON']):
                    
                    # add subject to the phrase
                    phrase += sub_tok.text

                    # save the root of the verb in phrase
                    phrase += ' '+token.lemma_ 

                    # check for noun or pronoun direct objects
                    for sub_tok in token.rights:
                        
                        # save the object in the phrase
                        if (sub_tok.dep_ in ['dobj']) and (sub_tok.pos_ in ['NOUN','PROPN']):
                                    
                            phrase += ' '+sub_tok.text
                            sent.append(phrase)
            
    return sent

# %%
# create a df containing sentence and its output for rule 3
row_list = []

for i in range(len(df2)):
    
    sent = df2.loc[i,'Sentence']
    year = df2.loc[i,'Year']
    output = rule3(sent)
    dict1 = {'Year':year,'Sentence':sent,'Output':output}
    row_list.append(dict1)
    
df_rule3 = pd.DataFrame(row_list)

# %%
# first 5 rows
df_rule3.head()
# Out:
#    Year  ...                     Output
# 0  1972  ...      [world make advances]
# 1  1972  ...                         []
# 2  1972  ...  [Union place limitations]
# 3  1972  ...                         []
# 4  1972  ...                         []
#
# [5 rows x 3 columns]

# %%
# selecting non-empty output rows
df_show = pd.DataFrame(columns=df_rule3.columns)

for row in range(len(df_rule3)):
    
    if len(df_rule3.loc[row,'Output'])!=0:
        df_show = df_show.append(df_rule3.loc[row,:])

# reset the index
df_show.reset_index(inplace=True, drop=True)

# %%
df_show.head()
# Out:
#    Year  ...                        Output
# 0  1972  ...         [world make advances]
# 1  1972  ...     [Union place limitations]
# 2  1972  ...  [Republic open negotiations]
# 3  1972  ...       [Korea intensify talks]
# 4  1972  ...     [process find reflection]
#
# [5 rows x 3 columns]

# %%
# number of outputs
df_show.shape
# Out:
# (3364, 3)

# %%
# separate subject, verb and object

verb_dict = dict()
dis_dict = dict()
dis_list = []

# iterating over all the sentences
for i in range(len(df_show)):
    
    # sentence containing the output
    sentence = df_show.loc[i,'Sentence']
    # year of the sentence
    year = df_show.loc[i,'Year']
    # output of the sentence
    output = df_show.loc[i,'Output']
    
    # iterating over all the outputs from the sentence
    for sent in output:
        
        # separate subject, verb and object
        n1, v, n2 = sent.split()[:1], sent.split()[1], sent.split()[2:]
        
        # append to list, along with the sentence
        dis_dict = {'Sentence':sentence,'Year':year,'Noun1':n1,'Verb':v,'Noun2':n2}
        dis_list.append(dis_dict)
        
        # counting the number of sentences containing the verb
        verb = sent.split()[1]
        if verb in verb_dict:
            verb_dict[verb]+=1
        else:
            verb_dict[verb]=1

df_sep = pd.DataFrame(dis_list)

# %%
# first 5 rows
df_sep.head()
# Out:
#                                             Sentence  ...           Noun2
# 0  During the past few years the world has made r...  ...      [advances]
# 1   The Soviet Union and the United States have a...  ...   [limitations]
# 2   The Federal Republic of Germany and the Germa...  ...  [negotiations]
# 3   And North and South Korea have intensified th...  ...         [talks]
# 4   If continued, this process will in time find ...  ...    [reflection]
#
# [5 rows x 5 columns]

# %%
# top 10 verbs
df_sep['Verb'].value_counts()[:10]
# Out:
# take       143
# make       119
# support     91
# give        79
# see         78
# face        55
# seek        52
# build       50
# pursue      48
# require     45
# Name: Verb, dtype: int64

# %%
# selecting a verb and looking at its patterns
df_sep[df_sep['Verb']=='support'].head(15)
# Out:
#                                               Sentence  ...            Noun2
# 14    And, in recognition of the importance of trad...  ...  [participation]
# 29    From the start the United States has supporte...  ...         [effort]
# 67     As we support the historic growth of democra...  ...         [growth]
# 79    We fully support the efforts of  the North At...  ...        [efforts]
# 151   That is why we have supported the efforts of ...  ...        [efforts]
# 172   As I think most Members know, I have strongly...  ...         [States]
# 245   The United States supports political and econ...  ...        [liberty]
# 265   Those names include a man who supported his w...  ...           [wife]
# 372   The United States strongly supports his leade...  ...     [leadership]
# 389   We must support the principles of non interve...  ...     [principles]
# 392   We strongly support the basis for a settlemen...  ...          [basis]
# 421   Sixthly, we support the effort of the newly e...  ...         [effort]
# 422   Sixthly, we support the effort of the newly e...  ...           [work]
# 424   We firmly support efforts, therefore, to redu...  ...        [efforts]
# 441   This is why my nation supports the growth of ...  ...         [growth]
#
# [15 rows x 5 columns]

# %% [markdown]
# ## 6. Rule 4: Relation Extraction part 2

# %% [markdown]
# Sample sentences from the dataset:
# 1.  With support from **many countries**, we have made **impressive progress**
# 2.  Because of their **unique expertise** and regional legitimacy, they can be instruments for solving some of the **hardest challenges** we face
# 3.  We are right to aim high and take on the **mightiest tasks**

# %%
from spacy import displacy 
displacy.render(nlp("With support from many countries, we have made impressive progress"), style='dep',jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="9518a8c79dde4c3094e57a14351c1ffe-0" class="displacy" width="1800" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">With</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">support</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">from</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">many</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">countries,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">we</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">have</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">made</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">impressive</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">progress</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9518a8c79dde4c3094e57a14351c1ffe-0-0" stroke-width="2px" d="M70,264.5 C70,2.0 1275.0,2.0 1275.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9518a8c79dde4c3094e57a14351c1ffe-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9518a8c79dde4c3094e57a14351c1ffe-0-1" stroke-width="2px" d="M70,264.5 C70,177.0 215.0,177.0 215.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9518a8c79dde4c3094e57a14351c1ffe-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M215.0,266.5 L223.0,254.5 207.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9518a8c79dde4c3094e57a14351c1ffe-0-2" stroke-width="2px" d="M245,264.5 C245,177.0 390.0,177.0 390.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9518a8c79dde4c3094e57a14351c1ffe-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M390.0,266.5 L398.0,254.5 382.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9518a8c79dde4c3094e57a14351c1ffe-0-3" stroke-width="2px" d="M595,264.5 C595,177.0 740.0,177.0 740.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9518a8c79dde4c3094e57a14351c1ffe-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,266.5 L587,254.5 603,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9518a8c79dde4c3094e57a14351c1ffe-0-4" stroke-width="2px" d="M420,264.5 C420,89.5 745.0,89.5 745.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9518a8c79dde4c3094e57a14351c1ffe-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M745.0,266.5 L753.0,254.5 737.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9518a8c79dde4c3094e57a14351c1ffe-0-5" stroke-width="2px" d="M945,264.5 C945,89.5 1270.0,89.5 1270.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9518a8c79dde4c3094e57a14351c1ffe-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,266.5 L937,254.5 953,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9518a8c79dde4c3094e57a14351c1ffe-0-6" stroke-width="2px" d="M1120,264.5 C1120,177.0 1265.0,177.0 1265.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9518a8c79dde4c3094e57a14351c1ffe-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1120,266.5 L1112,254.5 1128,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9518a8c79dde4c3094e57a14351c1ffe-0-7" stroke-width="2px" d="M1470,264.5 C1470,177.0 1615.0,177.0 1615.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9518a8c79dde4c3094e57a14351c1ffe-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1470,266.5 L1462,254.5 1478,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9518a8c79dde4c3094e57a14351c1ffe-0-8" stroke-width="2px" d="M1295,264.5 C1295,89.5 1620.0,89.5 1620.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9518a8c79dde4c3094e57a14351c1ffe-0-8" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1620.0,266.5 L1

# %%
# function for rule 4
def rule4(text):
    
    doc = nlp(text)

    pat = []
    
    # iterate over tokens
    for token in doc:
        phrase = ''
        # if the word is a subject noun or an object noun
        if (token.pos_ == 'NOUN')\
            and (token.dep_ in ['dobj','pobj','nsubj','nsubjpass']):
            
            # iterate over the children nodes
            for subtoken in token.children:
                # if word is an adjective or has a compound dependency
                if (subtoken.pos_ == 'ADJ') or (subtoken.dep_ == 'compound'):
                    phrase += subtoken.text + ' '
                    
            if len(phrase)!=0:
                phrase += token.text
             
        if  len(phrase)!=0:
            pat.append(phrase)
        
    
    return pat

# %%
# create a df containing sentence and its output for rule 4
row_list = []

for i in range(len(df2)):
    
    sent = df2.loc[i,'Sentence']
    year = df2.loc[i,'Year']
    # rule
    output = rule4(sent)
    
    dict1 = {'Year':year,'Sentence':sent,'Output':output}
    row_list.append(dict1)

df_rule4 = pd.DataFrame(row_list)

# %%
# first 5 rows
df_rule4.head()
# Out:
#    Year  ...                                             Output
# 0  1972  ...  [past few years, remarkable advances, Charter ...
# 1  1972  ...  [military confrontations, sovereign equality, ...
# 2  1972  ...  [precise limitations, next years, offensive mi...
# 3  1972  ...                                                 []
# 4  1972  ...          [specific provisions, unimpeded movement]
#
# [5 rows x 3 columns]

# %%
# selecting non-empty outputs
df_show = pd.DataFrame(columns=df_rule4.columns)

for row in range(len(df_rule4)):
    
    if len(df_rule4.loc[row,'Output'])!=0:
        df_show = df_show.append(df_rule4.loc[row,:])

# reset the index
df_show.reset_index(inplace=True, drop=True)

# %%
# number of matches 
df_show.shape
# Out:
# (6167, 3)

# %%
# first 15 rows
df_show.head(15)
# Out:
#     Year  ...                                             Output
# 0   1972  ...  [past few years, remarkable advances, Charter ...
# 1   1972  ...  [military confrontations, sovereign equality, ...
# 2   1972  ...  [precise limitations, next years, offensive mi...
# 3   1972  ...          [specific provisions, unimpeded movement]
# 4   1972  ...                [divided families, joint committee]
# 5   1972  ...                               [Charter objectives]
# 6   1972  ...                                     [old patterns]
# 7   1972  ...                              [positive reflection]
# 8   1972  ...                                 [Eastern capitals]
# 9   1972  ...        [stable military balance, force reductions]
# 10  1972  ...           [exploratory talks, next several months]
# 11  1972  ...  [more normal relationships, Europe relationships]
# 12  1972  ...                                     [crucial role]
# 13  1972  ...                                  [rigid divisions]
# 14  1972  ...  [other hand, normal relationship, better relat...
#
# [15 rows x 3 columns]

# %% [markdown]
# ### 7. Combining Rule 3 and Rule 4

# %% [markdown]
# Sample sentences:
# 1.  With support from many countries, **we** have **made impressive progress**
# 2. **It** will **require military planners** the world over to recognize that training for peace operations is a legitimate part of every nation security strategy

# %%
# modifying rule 4
def rule4_mod(text,index):
    
    doc = nlp(text)

    phrase = ''
    
    # iterate over tokens
    for token in doc:
        
        if token.i == index:
            
            # iterate over the children nodes
            for subtoken in token.children:
                # if word is an adjective
                if (subtoken.pos_ == 'ADJ') or (subtoken.dep_ == 'compound'):
                    phrase += ' '+subtoken.text
            break
    
    return phrase

# %%
# using rule 3 and rule 4
def rule3_mod(text):
    
    doc = nlp(text)
    
    sent = []
    
    for token in doc:
        # root word
        if (token.pos_=='VERB'):
            
            phrase =''
            
            # only extract noun or pronoun subjects
            for sub_tok in token.lefts:
                
                if (sub_tok.dep_ in ['nsubj','nsubjpass']) and (sub_tok.pos_ in ['NOUN','PROPN','PRON']):
                    
                    # look for subject modifier
                    adj = rule4_mod(text,sub_tok.i)
                    
                    phrase += adj + ' ' + sub_tok.text

                    # save the root word of the word
                    phrase += ' '+token.lemma_ 

                    # check for noun or pronoun direct objects
                    for sub_tok in token.rights:
                        
                        if (sub_tok.dep_ in ['dobj']) and (sub_tok.pos_ in ['NOUN','PROPN']):
                            
                            # look for object modifier
                            adj = rule4_mod(text,sub_tok.i)
                            
                            phrase += adj+' '+sub_tok.text
                            sent.append(phrase)
            
    return sent

# %%
# create a df containing sentence and its output for modified rule
row_list = []

for i in range(len(df2)):
    
    sent = df2.loc[i,'Sentence']
    year = df2.loc[i,'Year']
    output = rule3_mod(sent)
    dict1 = {'Year':year,'Sentence':sent,'Output':output}
    row_list.append(dict1)
    
df_rule = pd.DataFrame(row_list)

# %%
# first 5 rows
df_rule.head()
# Out:
#    Year  ...                                     Output
# 0  1972  ...          [ world make remarkable advances]
# 1  1972  ...                                         []
# 2  1972  ...  [ Soviet Union place precise limitations]
# 3  1972  ...                                         []
# 4  1972  ...                                         []
#
# [5 rows x 3 columns]

# %%
# selecting non-empty outputs
df_show_mod = pd.DataFrame(columns=df_rule.columns)

for row in range(len(df_rule)):
    
    if len(df_rule.loc[row,'Output'])!=0:
        df_show_mod = df_show_mod.append(df_rule.loc[row,:])

# reset the index
df_show_mod.reset_index(inplace=True, drop=True)

# %%
# number of matches
df_show_mod.shape
# Out:
# (3364, 3)

# %%
# first 15 rows
df_show_mod.head(20)
# Out:
#     Year  ...                                             Output
# 0   1972  ...                  [ world make remarkable advances]
# 1   1972  ...          [ Soviet Union place precise limitations]
# 2   1972  ...              [ Federal Republic open negotiations]
# 3   1972  ...                           [ Korea intensify talks]
# 4   1972  ...                [ process find positive reflection]
# 5   1972  ...                     [ conference prolong problems]
# 6   1972  ...                      [ conference reinforce trend]
# 7   1972  ...                 [ conference take practical steps]
# 8   1972  ...                 [ We study alternative approaches]
# 9   1972  ...               [ United States pursue general aims]
# 10  1972  ...                            [ we attach importance]
# 11  1972  ...                   [ United States intensify study]
# 12  1972  ...                                    [ me take note]
# 13  1972  ...                    [ growth rates exceed Alliance]
# 14  1972  ...                        [ we support participation]
# 15  1972  ...               [ United States reduce armed forces]
# 16  1972  ...              [ President Nixon propose cease fire]
# 17  1972  ...             [ President Nixon pledge major effort]
# 18  1972  ...                                    [ We take note]
# 19  1972  ...  [ Munich killings set deplorable patterns,  pa...
#
# [20 rows x 3 columns]

# %%
# Sample sentence
print(df_show_mod.loc[4,'Output'])
print(df_show_mod.loc[4,'Sentence'])
# Out:
# [' process find positive reflection']
#  If continued, this process will in time find positive reflection within the United Nations itself

# %%
# Sample sentence
print(df_show_mod.loc[17,'Output'])
print(df_show_mod.loc[17,'Sentence'])
# Out:
# [' President Nixon pledge major effort']
#  President Nixon has also pledged a major effort to assist both VietNamese States in post war reconstruction

# %% [markdown]
# ## 8. Rule 5: Patterns using Preposition

# %% [markdown]
# Sample sentences:
# 1.  We all believe the **benefits of globalization** must be allocated more broadly within and among societies
# 2. As the Millennium Summit reflected, we have no **shortage of** worthy **goals**
# 3. It should preserve the special **responsibility for peacekeeping** of the Security Council permanent members

# %%
# Sample sentence
from spacy import displacy 
displacy.render(nlp('''We all believe the benefits of globalization must 
be allocated more broadly within and among societies'''), 
                style='dep',jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="d3613179c6cc45be9a8e20d549c8808d-0" class="displacy" width="3025" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">We</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">all</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">believe</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">benefits</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">globalization</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">must</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">be</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">allocated</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">more</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">broadly</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">within</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">among</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">societies</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d3613179c6cc45be9a8e20d549c8808d-0-0" stroke-width="2px" d="M70,439.5 C70,264.5 385.0,264.5 385.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d3613179c6cc45be9a8e20d549c8808d-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,441.5 L62,429.5 78,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d3613179c6cc45be9a8e20d549c8808d-0-1" stroke-width="2px" d="M70,439.5 C70,352.0 205.0,352.0 205.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d3613179c6cc45be9a8e20d549c8808d-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">appos</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M205.0,441.5 L213.0,429.5 197.0,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d3613179c6cc45be9a8e20d549c8808d-0-2" stroke-width="2px" d="M595,439.5 C595,352.0 730.0,352.0 730.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d3613179c6cc45be9a8e20d549c8808d-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,441.5 L587,429.5 603,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d3613179c6cc45be9a8e20d549c8808d-0-3" stroke-width="2px" d="M770,439.5 C770,89.5 1795.0,89.5 1795.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d3613179c6cc45be9a8e20d549c8808d-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubjpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,441.5 L762,429.5 778,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d3613179c6cc45be9a8e20d549c8808d-0-4" stroke-width="2px" d="M770,439.5 C770,352.0 905.0,352.0 905.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d3613179c6cc45be9a8e20d549c8808d-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M905.0,441.5 L913.0,429.5 897.0,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d3613179c6cc45be9a8e20d549c8808d-0-5" stroke-width="2px" d="M945,439.5 C945,352.0 1080.0,352.0 1080.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d3613179c6cc45be9a8e20d549c8808d-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1080.0,441.5 L1088.0,

# %%
# rule 5 function
def rule5(text):
    
    doc = nlp(text)
    
    sent = []
    
    for token in doc:

        # look for prepositions
        if token.pos_=='ADP':

            phrase = ''
            
            # if its head word is a noun
            if token.head.pos_=='NOUN':
                
                # append noun and preposition to phrase
                phrase += token.head.text
                phrase += ' '+token.text

                # check the nodes to the right of the preposition
                for right_tok in token.rights:
                    # append if it is a noun or proper noun
                    if (right_tok.pos_ in ['NOUN','PROPN']):
                        phrase += ' '+right_tok.text
                
                if len(phrase)>2:
                    sent.append(phrase)
                
    return sent

# %%
# create a df containing sentence and its output for rule 5
row_list = []

for i in range(len(df2)):
    
    sent = df2.loc[i,'Sentence']
    year = df2.loc[i,'Year']
    
    # rule
    output = rule5(sent)
    
    dict1 = {'Year':year,'Sentence':sent,'Output':output}
    row_list.append(dict1)

df_rule = pd.DataFrame(row_list)

# %%
# first 5 rows
df_rule.head()
# Out:
#    Year  ...                                             Output
# 0  1972  ...        [advances toward goal, goal of, peace with]
# 1  1972  ...   [equality of countries, interference in affairs]
# 2  1972  ...                                                 []
# 3  1972  ...  [understanding between peoples, relations betw...
# 4  1972  ...                                                 []
#
# [5 rows x 3 columns]

# %%
# select non-empty outputs
df_show = pd.DataFrame(columns=df_rule.columns)

for row in range(len(df_rule)):
    
    if len(df_rule.loc[row,'Output'])!=0:
        df_show = df_show.append(df_rule.loc[row,:])

# reset the index
df_show.reset_index(inplace = True, drop = True)

# %%
# first 5 rows
df_show.head()
# Out:
#    Year  ...                                             Output
# 0  1972  ...        [advances toward goal, goal of, peace with]
# 1  1972  ...   [equality of countries, interference in affairs]
# 2  1972  ...  [understanding between peoples, relations betw...
# 3  1972  ...                           [negotiations on treaty]
# 4  1972  ...  [talks on plight, plight of families, problems...
#
# [5 rows x 3 columns]

# %%
# separate noun, preposition and noun

prep_dict = dict()
dis_dict = dict()
dis_list = []

# iterating over all the sentences
for i in range(len(df_show)):
    
    # sentence containing the output
    sentence = df_show.loc[i,'Sentence']
    # year of the sentence
    year = df_show.loc[i,'Year']
    # output of the sentence
    output = df_show.loc[i,'Output']
    
    # iterating over all the outputs from the sentence
    for sent in output:
        
        # separate subject, verb and object
        n1, p, n2 = sent.split()[0], sent.split()[1], sent.split()[2:]
        
        # append to list, along with the sentence
        dis_dict = {'Sentence':sentence,'Year':year,'Noun1':n1,'Preposition':p,'Noun2':n2}
        dis_list.append(dis_dict)
        
        # counting the number of sentences containing the verb
        prep = sent.split()[1]
        if prep in prep_dict:
            prep_dict[prep]+=1
        else:
            prep_dict[prep]=1

df_sep= pd.DataFrame(dis_list)

# %%
# first 10 rows
df_sep.head(10)
# Out:
#                                             Sentence  ...        Noun2
# 0  During the past few years the world has made r...  ...       [goal]
# 1  During the past few years the world has made r...  ...           []
# 2  During the past few years the world has made r...  ...           []
# 3   In 1972 alone, the United States and the Sovi...  ...  [countries]
# 4   In 1972 alone, the United States and the Sovi...  ...    [affairs]
# 5   The United States and the People Republic of ...  ...    [peoples]
# 6   The United States and the People Republic of ...  ...           []
# 7   The United States and the People Republic of ...  ...     [States]
# 8   The United States and the People Republic of ...  ...       [Asia]
# 9   The United States and the People Republic of ...  ...      [world]
#
# [10 rows x 5 columns]

# %%
# top 10 prepositions
df_sep['Preposition'].value_counts()[:10]
# Out:
# of         6123
# in         1239
# for         890
# to          576
# on          364
# with        249
# between     204
# from        146
# against     126
# by           89
# Name: Preposition, dtype: int64

# %%
# selecting a preposition and looking at its patterns
df_sep[df_sep['Preposition'] == 'against'].head(10)
# Out:
#                                               Sentence  ...           Noun2
# 103   This fact has often been cited in attacks aga...  ...              []
# 137   The United Nations can also make a substantia...  ...       [traffic]
# 180   But political passion, however deeply held, c...  ...       [persons]
# 181   Certainly the terrorist acts I have cited are...  ...        [fabric]
# 201   The draft articles on the prevention and puni...  ...        [agents]
# 221    These actions would mark a major advance in ...  ...     [terrorism]
# 231   A  great struggle against dictatorship had be...  ...  [dictatorship]
# 340   Therefore, we are working towards a cooperati...  ...       [attacks]
# 376     And in the face of today changes, with the ...  ...         [trade]
# 377     And in the face of today changes, with the ...  ...        [people]
#
# [10 rows x 5 columns]
